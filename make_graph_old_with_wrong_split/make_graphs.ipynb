# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import json
df = pd.read_csv('global_results.csv')
print(df.to_string(index=False))
# Out:
#           timestamp                                           model_name                                                                                                                               parameters  train_max_acc  train_round  train_loss  val_max_acc  val_round  val_loss  test_max_acc  test_round  test_loss
# 2025-08-05 04:45:13                                                  fed         {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 4, "GAMMA": 0.15, "momentum": 0.9}         0.0176            4      4.5900       0.0204          4    4.5891        0.0189           3     4.5964
# 2025-08-05 04:48:47                                       fed_gamma_0.23         {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2, "GAMMA": 0.23, "momentum": 0.9}         0.0168            2      4.6024       0.0174          2    4.6031        0.0169           2     4.6024
# 2025-08-05 04:49:00                                       fed_gamma_0.11         {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2, "GAMMA": 0.11, "momentum": 0.9}         0.0129            1      4.6039       0.0134          1    4.6045        0.0150           2     4.6001
# 2025-08-05 04:49:13                                       fed_gamma_0.05         {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2, "GAMMA": 0.05, "momentum": 0.9}         0.0158            2      4.5998       0.0128          1    4.6049        0.0171           1     4.6033
# 2025-08-05 04:49:26                                       fed_gamma_0.06         {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2, "GAMMA": 0.06, "momentum": 0.9}         0.0101            1      4.6046       0.0074          1    4.6047        0.0098           2     4.6016
# 2025-08-05 04:49:39                                          fed_gamma_2            {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2, "GAMMA": 2, "momentum": 0.9}         0.0111            1      4.6053       0.0118          1    4.6056        0.0101           1     4.6054
# 2025-08-05 05:06:35                                          fed_gamma_1            {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2, "GAMMA": 1, "momentum": 0.9}         0.0137            1      4.6034       0.0136          1    4.6032        0.0152           1     4.6034
# 2025-08-05 05:18:42                               fed_gamma_1_dirichlet1          {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 100, "GAMMA": 1, "momentum": 0.9}         0.2657           99      2.9699       0.2496        100    3.1113        0.2612         100     3.0844
# 2025-08-05 05:32:24                               fed_gamma_1_dirichlet2          {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 100, "GAMMA": 1, "momentum": 0.9}         0.2018           99      4.3272       0.1808         83    4.2289        0.1865          99     4.7264
# 2025-08-05 06:19:11                         fed_gamma_uniform_dirichlet2   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 10, "GAMMA": "uniform", "momentum": 0.9}         0.0570           10      4.2176       0.0542         10    4.2139        0.0614          10     4.2084
# 2025-08-06 17:29:30                 fed_gamma_0.01_dirichlet_new_version       {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 200, "GAMMA": 0.01, "momentum": 0.9}         0.3685          199      2.4727       0.3152        196    2.8726        0.3320         199     2.8027
# 2025-08-07 13:39:36                          hetetogeneous_shard_iid_J_4  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 200, "GAMMA": "uniform", "momentum": 0.9}         0.3666          200      2.4702       0.3196        200    2.8525        0.3314         197     2.7774
# 2025-08-07 14:15:41                          hetetogeneous_shard_iid_J_8  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 100, "GAMMA": "uniform", "momentum": 0.9}         0.3295          100      2.8849       0.2712         91    3.6344        0.2833         100     3.5241
# 2025-08-07 14:31:01                         hetetogeneous_shard_iid_J_16  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.2647           50      3.6660       0.2268         49    4.4454        0.2253          50     4.4216
# 2025-08-07 14:48:46                    hetetogeneous_shard_non_iid_1_J_8  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 100, "GAMMA": "uniform", "momentum": 0.9}         0.0242           80      5.3503       0.0236         79    5.2909        0.0255          80     5.2368
# 2025-08-07 15:04:33                   hetetogeneous_shard_non_iid_1_J_16  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.0125           26      4.8587       0.0132         38    4.9583        0.0128          38     4.9206
# 2025-08-07 15:22:27                    hetetogeneous_shard_non_iid_5_J_8  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 100, "GAMMA": "uniform", "momentum": 0.9}         0.0185           94      4.9907       0.0188         96    4.8797        0.0190          89     5.4428
# 2025-08-07 15:37:37                   hetetogeneous_shard_non_iid_5_J_16  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.0170           44      5.9964       0.0184         44    5.9949        0.0179          44     5.9531
# 2025-08-07 15:55:30                   hetetogeneous_shard_non_iid_10_J_8  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 100, "GAMMA": "uniform", "momentum": 0.9}         0.0205           71      5.0999       0.0210         91    5.1882        0.0207          98     4.9421
# 2025-08-07 16:11:02                  hetetogeneous_shard_non_iid_10_J_16  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.0159           48      5.0480       0.0180         48    5.0373        0.0160          48     5.0135
# 2025-08-07 16:29:00                   hetetogeneous_shard_non_iid_50_J_8  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 100, "GAMMA": "uniform", "momentum": 0.9}         0.0186           87      5.2990       0.0198         87    5.2995        0.0188          87     5.2523
# 2025-08-07 16:44:33                  hetetogeneous_shard_non_iid_50_J_16  {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.0164           49      4.8876       0.0166         49    4.8720        0.0164          44     4.9683
# 2025-08-08 13:00:31                  hetetogeneous_shard_iid_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 3, "GAMMA": "uniform", "momentum": 0.9}         0.0109            3      4.5997       0.0124          3    4.5998        0.0107           2     4.6019
# 2025-08-08 13:00:40                  hetetogeneous_shard_iid_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1, "GAMMA": "uniform", "momentum": 0.9}         0.0166            1      4.5987       0.0158          1    4.5991        0.0205           1     4.5970
# 2025-08-08 13:00:41                 hetetogeneous_shard_iid_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 0, "GAMMA": "uniform", "momentum": 0.9}         0.0166            1      4.5987       0.0158          1    4.5991        0.0205           1     4.5970
# 2025-08-08 13:00:59            hetetogeneous_shard_non_iid_1_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 3, "GAMMA": "uniform", "momentum": 0.9}         0.0101            2      5.4512       0.0100          1   12.2506        0.0100           1    10.1509
# 2025-08-08 13:01:09            hetetogeneous_shard_non_iid_1_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1, "GAMMA": "uniform", "momentum": 0.9}         0.0098            1      5.7697       0.0116          1    5.7711        0.0100           1     5.4954
# 2025-08-08 13:01:09           hetetogeneous_shard_non_iid_1_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 0, "GAMMA": "uniform", "momentum": 0.9}         0.0098            1      5.7697       0.0116          1    5.7711        0.0100           1     5.4954
# 2025-08-08 13:01:28            hetetogeneous_shard_non_iid_5_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 3, "GAMMA": "uniform", "momentum": 0.9}         0.0102            1      9.4341       0.0096          2    5.1118        0.0100           1     8.2838
# 2025-08-08 13:01:38            hetetogeneous_shard_non_iid_5_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1, "GAMMA": "uniform", "momentum": 0.9}         0.0100            1     42.7505       0.0100          1   42.8300        0.0100           1    35.4392
# 2025-08-08 13:01:38           hetetogeneous_shard_non_iid_5_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 0, "GAMMA": "uniform", "momentum": 0.9}         0.0100            1     42.7505       0.0100          1   42.8300        0.0100           1    35.4392
# 2025-08-08 13:01:57           hetetogeneous_shard_non_iid_10_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 3, "GAMMA": "uniform", "momentum": 0.9}         0.0143            1      7.6873       0.0136          1    7.6500        0.0181           1     6.9635
# 2025-08-08 13:02:07           hetetogeneous_shard_non_iid_10_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1, "GAMMA": "uniform", "momentum": 0.9}         0.0099            1     17.5041       0.0106          1   17.5462        0.0100           1    15.0642
# 2025-08-08 13:02:07          hetetogeneous_shard_non_iid_10_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 0, "GAMMA": "uniform", "momentum": 0.9}         0.0099            1     17.5041       0.0106          1   17.5462        0.0100           1    15.0642
# 2025-08-08 13:02:26           hetetogeneous_shard_non_iid_50_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 3, "GAMMA": "uniform", "momentum": 0.9}         0.0102            1      6.6689       0.0102          3    6.5535        0.0100           1     6.2872
# 2025-08-08 13:02:35           hetetogeneous_shard_non_iid_50_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1, "GAMMA": "uniform", "momentum": 0.9}         0.0100            1      6.8591       0.0114          1    6.8346        0.0100           1     6.3636
# 2025-08-08 13:02:35          hetetogeneous_shard_non_iid_50_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 0, "GAMMA": "uniform", "momentum": 0.9}         0.0100            1      6.8591       0.0114          1    6.8346        0.0100           1     6.3636
# 2025-08-08 13:08:28                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 10, "GAMMA": "uniform", "momentum": 0.9}         0.0492           10      4.3476       0.0526         10    4.3429        0.0494          10     4.3390
# 2025-08-08 13:09:07                  hetetogeneous_shard_iid_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 5, "GAMMA": "uniform", "momentum": 0.9}         0.0100            0      6.8591       0.0114          0    6.8346        0.0100           0     6.3636
# 2025-08-08 13:17:46                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 10, "GAMMA": "uniform", "momentum": 0.9}         0.0528           10      4.2776       0.0498         10    4.2725        0.0505          10     4.2755
# 2025-08-08 13:18:39                  hetetogeneous_shard_iid_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 5, "GAMMA": "uniform", "momentum": 0.9}         0.0643            5      4.1930       0.0610          5    4.1955        0.0635           5     4.1896
# 2025-08-08 13:19:16                 hetetogeneous_shard_iid_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 2, "GAMMA": "uniform", "momentum": 0.9}         0.0610            2      4.2465       0.0624          2    4.2473        0.0631           2     4.2422
# 2025-08-08 13:20:23            hetetogeneous_shard_non_iid_1_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 10, "GAMMA": "uniform", "momentum": 0.9}         0.0122            1      7.7526       0.0134          1    7.7892        0.0114           9     9.9527
# 2025-08-08 13:21:16            hetetogeneous_shard_non_iid_1_J_8_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 5, "GAMMA": "uniform", "momentum": 0.9}         0.0104            5      4.7137       0.0108          1    6.8310        0.0107           5     4.6971
# 2025-08-08 13:21:52           hetetogeneous_shard_non_iid_1_J_16_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 2, "GAMMA": "uniform", "momentum": 0.9}         0.0102            2      5.1600       0.0106          1    4.6843        0.0100           1     4.6815
# 2025-08-08 15:09:50                  hetetogeneous_shard_iid_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 6, "GAMMA": "uniform", "momentum": 0.9}         0.0235            5      4.5847       0.0242          5    4.5841        0.0284           5     4.5836
# 2025-08-08 15:10:31            hetetogeneous_shard_non_iid_1_J_4_LR_0.01    {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 6, "GAMMA": "uniform", "momentum": 0.9}         0.0102            2      5.0228       0.0118          6    4.9047        0.0100           1     8.1146
# 2025-08-08 15:13:09                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 12, "GAMMA": "uniform", "momentum": 0.9}         0.0653           12      4.1662       0.0614         11    4.2340        0.0654          12     4.1568
# 2025-08-08 15:14:24            hetetogeneous_shard_non_iid_1_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 12, "GAMMA": "uniform", "momentum": 0.9}         0.0150           10      5.0985       0.0132         12    4.6941        0.0146          10     4.9693
# 2025-08-08 15:17:20                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 20, "GAMMA": "uniform", "momentum": 0.9}         0.0926           20      3.9524       0.0960         20    3.9595        0.0950          20     3.9414
# 2025-08-08 15:18:48            hetetogeneous_shard_non_iid_1_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 20, "GAMMA": "uniform", "momentum": 0.9}         0.0106           13      4.9558       0.0124         11   22.5026        0.0109          13     4.9718
# 2025-08-08 15:31:17                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 70, "GAMMA": "uniform", "momentum": 0.9}         0.2150           69      3.2476       0.2094         63    3.3659        0.2145          68     3.3246
# 2025-08-08 15:46:39                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 19, "GAMMA": "uniform", "momentum": 0.9}         0.0904           19      3.9703       0.0916         19    3.9720        0.0972          18     3.9763
# 2025-08-08 15:48:34            hetetogeneous_shard_non_iid_1_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 19, "GAMMA": "uniform", "momentum": 0.9}         0.0136           19      4.6968       0.0148         19    4.6916        0.0146          19     4.6734
# 2025-08-08 15:53:58                  hetetogeneous_shard_iid_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.1803           49      3.4308       0.1790         49    3.4796        0.1810          50     3.4904
# 2025-08-08 15:58:01            hetetogeneous_shard_non_iid_1_J_4_LR_0.01   {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 50, "GAMMA": "uniform", "momentum": 0.9}         0.0122           45      5.2818       0.0128         45    5.2687        0.0124          45     5.1620
# 2025-08-08 19:16:20                  hetetogeneous_shard_iid_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.8723         1995      0.4008       0.4374       1961    4.0792        0.4539        1878     4.1963
# 2025-08-08 22:36:49            hetetogeneous_shard_non_iid_1_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.2034         1993      3.1512       0.1926       1951    3.3638        0.2134        1993     3.1206
# 2025-08-09 06:09:38                  hetetogeneous_shard_iid_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.7609          998      0.8210       0.3952        996    4.2132        0.4023         922     4.3965
# 2025-08-09 08:24:13                 hetetogeneous_shard_iid_J_16_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.5878          495      1.6257       0.3442        500    4.2168        0.3494         500     4.3507
# 2025-08-09 11:02:10            hetetogeneous_shard_non_iid_1_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.1176          984      3.7846       0.1224        913    3.7992        0.1362         913     3.7161
# 2025-08-09 13:16:13           hetetogeneous_shard_non_iid_1_J_16_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0650          464      4.2190       0.0672        450    4.1788        0.0723         450     4.1493
# 2025-08-09 17:50:23            hetetogeneous_shard_non_iid_5_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.1548         1856      3.5123       0.1578       1856    3.5536        0.1734        1916     3.4405
# 2025-08-09 20:59:35            hetetogeneous_shard_non_iid_5_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.1170          947      3.7847       0.1158        947    3.8085        0.1307         947     3.7172
# 2025-08-10 04:19:04            hetetogeneous_shard_non_iid_5_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.1548         1856      3.5123       0.1578       1856    3.5536        0.1734        1916     3.4405
# 2025-08-10 04:20:40            hetetogeneous_shard_non_iid_5_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.1548         1856      3.5123       0.1578       1856    3.5536        0.1734        1916     3.4405
# 2025-08-10 04:20:40            hetetogeneous_shard_non_iid_5_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.1170          947      3.7847       0.1158        947    3.8085        0.1307         947     3.7172
# 2025-08-10 04:26:55           hetetogeneous_shard_non_iid_10_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.2090         1959      3.1348       0.2062       1959    3.2063        0.2222        1959     3.1141
# 2025-08-09 18:54:38           hetetogeneous_shard_non_iid_5_J_16_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0699          496      4.2093       0.0698        496    4.1931        0.0740         496     4.1399
# 2025-08-09 21:46:25          hetetogeneous_shard_non_iid_10_J_16_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0800          492      4.1547       0.0760        495    4.0372        0.0860         495     3.9801
# 2025-08-10 00:34:35          hetetogeneous_shard_non_iid_50_J_16_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0718          448      4.4620       0.0692        474    4.2075        0.0722         448     4.4524
# 2025-08-10 07:30:10           hetetogeneous_shard_non_iid_10_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.1216          956      3.7483       0.1200        956    3.7622        0.1324         956     3.6737
# 2025-08-10 12:32:41            hetetogeneous_shard_non_iid_5_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.1548         1856      3.5123       0.1578       1856    3.5536        0.1734        1916     3.4405
# 2025-08-10 12:32:41            hetetogeneous_shard_non_iid_5_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.1170          947      3.7847       0.1158        947    3.8085        0.1307         947     3.7172
# 2025-08-10 12:32:41           hetetogeneous_shard_non_iid_10_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.2090         1959      3.1348       0.2062       1959    3.2063        0.2222        1959     3.1141
# 2025-08-10 12:32:41           hetetogeneous_shard_non_iid_10_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.1216          956      3.7483       0.1200        956    3.7622        0.1324         956     3.6737
# 2025-08-10 12:53:31           hetetogeneous_shard_non_iid_50_J_4_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 4, "ROUNDS": 2000, "GAMMA": "uniform", "momentum": 0.9}         0.1703         1844      3.3606       0.1648       1839    3.4657        0.1854        1844     3.3182
# 2025-08-10 07:27:45  hetetogeneous_WD_1e-05_shard_non_iid_5_J_16_LR_0.01  {"lr": 0.01, "weight_decay": 1e-05, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0131           11      4.6428       0.0130         11    4.6373        0.0157          11     4.6406
# 2025-08-10 10:16:51 hetetogeneous_WD_1e-05_shard_non_iid_10_J_16_LR_0.01  {"lr": 0.01, "weight_decay": 1e-05, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0754          492      4.1955       0.0746        492    4.1953        0.0791         492     4.1359
# 2025-08-10 12:46:50 hetetogeneous_WD_1e-05_shard_non_iid_50_J_16_LR_0.01  {"lr": 0.01, "weight_decay": 1e-05, "batch_size": 128, "K": 100, "C": 0.1, "J": 16, "ROUNDS": 500, "GAMMA": "uniform", "momentum": 0.9}         0.0609          448      4.4647       0.0588        338    4.3366        0.0645         448     4.4610
# 2025-08-10 15:52:49           hetetogeneous_shard_non_iid_50_J_8_LR_0.01 {"lr": 0.01, "weight_decay": 0.0001, "batch_size": 128, "K": 100, "C": 0.1, "J": 8, "ROUNDS": 1000, "GAMMA": "uniform", "momentum": 0.9}         0.0996          960      3.8560       0.1006        960    3.8573        0.1091         930     3.8142

# %%
data = """timestamp,model_name,parameters,train_max_acc,train_round,train_loss,val_max_acc,val_round,val_loss,test_max_acc,test_round,test_loss
2025-08-08 19:16:20,hetetogeneous_shard_iid_J_4_LR_0.01,"{""lr"": 0.01, ""weight_decay"": 0.0001, ""batch_size"": 128, ""K"": 100, ""C"": 0.1, ""J"": 4, ""ROUNDS"": 2000, ""GAMMA"": ""uniform"", ""momentum"": 0.9}",0.8723,1995,0.4008,0.4374,1961,4.0792,0.4539,1878,4.1963
2025-08-08 22:36:49,hetetogeneous_shard_non_iid_1_J_4_LR_0.01,"{""lr"": 0.01, ""weight_decay"": 0.0001, ""batch_size"": 128, ""K"": 100, ""C"": 0.1, ""J"": 4, ""ROUNDS"": 2000, ""GAMMA"": ""uniform"", ""momentum"": 0.9}",0.2034,1993,3.1512,0.1926,1951,3.3638,0.2134,1993,3.1206
... (rest of your data) ...
"""

# Read CSV


# Extract J value from model_name
""" pattern = r'shard_(.+?)_J_(\d+)_'
df = df[df['model_name'].str.contains(pattern, regex=True)].copy()

# Extract dataset_type and J safely
df['dataset_type'] = df['model_name'].apply(lambda x: re.search(pattern, x).group(1))
df['J'] = df['model_name'].apply(lambda x: int(re.search(pattern, x).group(2)))

# Plot
plt.figure(figsize=(10, 6))
for dtype, group in df.groupby('dataset_type'):
    plt.scatter(group['J'], group['test_max_acc'], label=dtype, s=80)

plt.xlabel('J value')
plt.ylabel('Test Max Accuracy')
plt.title('Test Accuracy by J value and Dataset Type')
plt.legend(title="Dataset Type")
plt.grid(True)
plt.show() """
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_11733/317695064.py:11: SyntaxWarning: invalid escape sequence '\d'
#   """ pattern = r'shard_(.+?)_J_(\d+)_'
# ' pattern = r\'shard_(.+?)_J_(\\d+)_\'\ndf = df[df[\'model_name\'].str.contains(pattern, regex=True)].copy()\n\n# Extract dataset_type and J safely\ndf[\'dataset_type\'] = df[\'model_name\'].apply(lambda x: re.search(pattern, x).group(1))\ndf[\'J\'] = df[\'model_name\'].apply(lambda x: int(re.search(pattern, x).group(2)))\n\n# Plot\nplt.figure(figsize=(10, 6))\nfor dtype, group in df.groupby(\'dataset_type\'):\n    plt.scatter(group[\'J\'], group[\'test_max_acc\'], label=dtype, s=80)\n\nplt.xlabel(\'J value\')\nplt.ylabel(\'Test Max Accuracy\')\nplt.title(\'Test Accuracy by J value and Dataset Type\')\nplt.legend(title="Dataset Type")\nplt.grid(True)\nplt.show() '

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("res_heterogenous.csv")

# Remove duplicates ignoring the timestamp column
df_unique = df.drop_duplicates(subset=df.columns.difference(['timestamp']))

# Save the cleaned CSV
df_unique.to_csv("no_duplicate_res_heterogenous.csv", index=False)

print(f"Original rows: {len(df)}, Unique rows: {len(df_unique)}")
# Out:
# Original rows: 22, Unique rows: 15

# %%
pattern = r'shard_(.+?)_J_(\d+)_'

df = df_unique[df_unique['model_name'].str.contains(pattern, regex=True)].copy()
df['dataset_type'] = df['model_name'].apply(lambda x: re.search(pattern, x).group(1))
df['J'] = df['parameters'].apply(lambda x: json.loads(x.replace('""', '"'))['J'])
df_sorted = df.sort_values(by='J')
print(df_sorted[['dataset_type', 'J']])
# Out:
#    dataset_type   J
# 0           iid   4
# 1     non_iid_1   4
# 6     non_iid_5   4
# 11   non_iid_10   4
# 20   non_iid_50   4
# 4     non_iid_1   8
# 7     non_iid_5   8
# 2           iid   8
# 15   non_iid_10   8
# 21   non_iid_50   8
# 5     non_iid_1  16
# 3           iid  16
# 14   non_iid_50  16
# 13   non_iid_10  16
# 12    non_iid_5  16
# /tmp/ipykernel_11733/2336250741.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df_unique[df_unique['model_name'].str.contains(pattern, regex=True)].copy()

# %%
plt.figure(figsize=(10, 6))
for dtype, group in df.groupby('dataset_type'):
    plt.scatter(group['J'], group['test_max_acc'], label=dtype, s=80)

plt.xlabel('J value')
plt.ylabel('Test Max Accuracy')
plt.title('Test Accuracy by J value and Dataset Type')
plt.legend(title="Dataset Type")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
for dtype, group in df.groupby('J'):
    plt.scatter(group['dataset_type'], group['test_max_acc'], label=dtype, s=80)

plt.xlabel('Dataset Type')
plt.ylabel('Test Max Accuracy')
plt.title('Test Accuracy by J value and Dataset Type')
plt.legend(title="J")
plt.grid(True)
plt.show()

# %%
pattern = r'shard_(.+?)_J_(\d+)_'
df = df[df['model_name'].str.contains(pattern, regex=True)].copy()

# Extract dataset_type and J safely
df['dataset_type'] = df['model_name'].apply(lambda x: re.search(pattern, x).group(1))
df['J'] = df['model_name'].apply(lambda x: int(re.search(pattern, x).group(2)))

# Plot
plt.figure(figsize=(10, 6))
for dtype, group in df.groupby('dataset_type'):
    plt.scatter(group['J'], group['test_max_acc'], label=dtype, s=80)

plt.xlabel('J value')
plt.ylabel('Test Max Accuracy')
plt.title('Test Accuracy by J value and Dataset Type')
plt.legend(title="Dataset Type")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_11733/58156431.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df[df['model_name'].str.contains(pattern, regex=True)].copy()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of gamma values and corresponding file names
gammas = [0.01,0.1, 0.5, 1, 10]
base_path = './fedavg_results_gamma_{}.csv'

# Set up the plot
plt.figure(figsize=(12, 6))

# Load and plot each CSV
for gamma in gammas:
    file_path = base_path.format(gamma)
    df = pd.read_csv(file_path)

    plt.plot(df['round'], df['test_acc'], label=f'γ = {gamma}')
    print(f"Gamma {gamma}: Max Test Acc = {df['test_acc'].max():.4f}")


# Configure plot
plt.xlabel('Federated Round')
plt.ylabel('Global Test Accuracy')
plt.title('FedAvg CIFAR-100: Test Accuracy vs Rounds for Different γ')
plt.grid(True)
plt.legend(title="Gamma")
plt.tight_layout()
plt.show()
