# %%
# ── A. Imports & Reproducibility ────────────────────────────────────────────────
import os, copy
import csv                                                  # For result logging :contentReference[oaicite:0]{index=0}
import random                                               # For seeding :contentReference[oaicite:1]{index=1}
import numpy as np                                          # For numeric ops :contentReference[oaicite:2]{index=2}
import torch                                               # Core PyTorch :contentReference[oaicite:3]{index=3}
import torch.nn as nn                                       # Neural-net modules :contentReference[oaicite:4]{index=4}
import torch.nn.functional as F                             # Functional API :contentReference[oaicite:5]{index=5}
import torch.optim as optim                                 # Optimizers :contentReference[oaicite:6]{index=6}
from torch.optim.lr_scheduler import CosineAnnealingLR      # Scheduler :contentReference[oaicite:7]{index=7}
from torch.utils.data import DataLoader, random_split       # Data loaders & splits :contentReference[oaicite:8]{index=8}
import torchvision                                          # Datasets & transforms :contentReference[oaicite:9]{index=9}
import torchvision.transforms as T                          # Transforms :contentReference[oaicite:10]{index=10}
from torch.utils.tensorboard import SummaryWriter           # TensorBoard logging :contentReference[oaicite:11]{index=11}
import matplotlib.pyplot as plt                             # Plotting :contentReference[oaicite:12]{index=12}

# %%
# Seed everything for reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)


# ── B. Device ───────────────────────────────────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")                             # Confirm GPU vs CPU :contentReference[oaicite:13]{index=13}



# ── C. Data Preparation ─────────────────────────────────────────────────────────
# Transforms
transform_train = T.Compose([
    T.RandomCrop(32, padding=4), T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize((0.5071,0.4867,0.4408),(0.2675,0.2565,0.2761)),
])
transform_test = T.Compose([
    T.ToTensor(),
    T.Normalize((0.5071,0.4867,0.4408),(0.2675,0.2565,0.2761)),
])
# Out:
# Using device: cuda

# %%
import glob, torch, os

def latest_ckpt(dirpath, pattern=None):
    """
    If you pass pattern=None, we'll look for anything matching
    *_last_ckpt_round_*.pth and return the numerically latest file.
    """
    if pattern is None:
        pattern = "*_last_ckpt_round_*.pth"
    paths = glob.glob(os.path.join(dirpath, pattern))
    if not paths:
        return None
    # Extract the round number from each filename, assuming it ends in _<round>.pth
    def round_num(p):
        base = os.path.basename(p)
        # splits on underscores: shard_J{J}_last_ckpt_round_{rnd}.pth
        return int(base.rsplit("_",1)[1].split(".")[0])
    paths.sort(key=round_num)
    return paths[-1]


def load_checkpoint(model, optimizer, ckpt_dir, shard_key, J, resume=True):
    if not resume:
        return 1
    pat = f"{shard_key}_J{J}_last_ckpt_round_*.pth"
    ckpt_path = latest_ckpt(ckpt_dir, pat)
    if ckpt_path is None:
        return 1
    ckpt = torch.load(ckpt_path, map_location='cpu')
    model.load_state_dict(ckpt['model_state'])
    optimizer.load_state_dict(ckpt['optimizer_state'])
    rng_state = ckpt['rng_state']
    if rng_state.device.type != 'cpu':
        rng_state = rng_state.cpu()
    torch.set_rng_state(rng_state)
    return ckpt['round'] + 1



def save_checkpoint(model, optimizer, round_num, ckpt_dir,
                    shard_key, J, is_best=False):
    """
    Saves:
      <shard_key>_J<J>_last_ckpt_round_<round_num>.pth
    and if is_best=True, also
      <shard_key>_J<J>_best_ckpt.pth
    """
    prefix = f"{shard_key}_J{J}"
    state = {
        'round': round_num,
        'model_state': model.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'rng_state': torch.get_rng_state(),
    }
    # unique filename per config
    last_name = f"{prefix}_last_ckpt_round_{round_num}.pth"
    torch.save(state, os.path.join(ckpt_dir, last_name))
    if is_best:
        best_name = f"{prefix}_best_ckpt.pth"
        torch.save(model.state_dict(), os.path.join(ckpt_dir, best_name))
    print(f"[Checkpoint] Saved {last_name}")

# %%
# ── C. Data Preparation ─────────────────────────────────────────────────────────
# Transforms (as before)…

# Download full CIFAR‑100 training set
full_train = torchvision.datasets.CIFAR100(
    root='./data', train=True, download=True, transform=transform_train
)

# 1) Centralized validation split
val_size   = 5000
train_size = len(full_train) - val_size
train_dataset, val_dataset = random_split(
    full_train,
    [train_size, val_size],
    generator=torch.Generator().manual_seed(seed)
)

# ── C.1 Build validation loader ───────────────────────────────
BS_VAL = 256
val_loader = DataLoader(
    val_dataset,
    batch_size=BS_VAL,
    shuffle=False,
    num_workers=2
)

# Ensure test_loader exists (fix NameError from summarize_run)
if 'test_loader' not in globals():
    print("Defining test_loader (was missing).")
    # require transform_test and BS_VAL to be defined
    if 'transform_test' not in globals():
        # fallback: define a default transform (shouldn't happen if you defined it earlier)
        transform_test = T.Compose([
            T.ToTensor(),
            T.Normalize((0.5071,0.4867,0.4408),(0.2675,0.2565,0.2761)),
        ])
    test_dataset = torchvision.datasets.CIFAR100(
        './data', train=False, download=True, transform=transform_test
    )
    test_loader = DataLoader(test_dataset, batch_size=BS_VAL, shuffle=False, num_workers=2)
else:
    print("test_loader already defined in scope.")

# ── C.2 Non-IID Sharding Helper ────────────────────────────────────────────────

from collections import defaultdict, deque
from torch.utils.data import Subset

def create_labelwise_shards(dataset, K, Nc, seed=42):
    # 1) Group indices by label
    label2idx = defaultdict(list)
    for idx, (_, lbl) in enumerate(dataset):
        label2idx[lbl].append(idx)

    # 2) Shuffle each label’s pool
    rng = random.Random(seed)
    for lbl in label2idx:
        rng.shuffle(label2idx[lbl])

    # 3) Prepare an iterator per label
    pointers = {lbl: 0 for lbl in label2idx}

    # 4) Build shards
    samples_per_client = len(dataset) // K
    shards_idx = []
    labels_cycle = list(label2idx.keys())

    for client_id in range(K):
        client_idxs = []
        # Rotate start point so clients don’t always pick the same first label
        rng.shuffle(labels_cycle)
        for lbl in labels_cycle:
            if len(client_idxs) >= samples_per_client:
                break
            # How many to take from this label
            needed = samples_per_client - len(client_idxs)
            available = len(label2idx[lbl]) - pointers[lbl]
            take = min(needed, available)
            if take > 0:
                start = pointers[lbl]
                end   = start + take
                client_idxs.extend(label2idx[lbl][start:end])
                pointers[lbl] += take
        # If we still haven’t reached samples_per_client (rare), fill randomly
        if len(client_idxs) < samples_per_client:
            all_remaining = [i for lbl in label2idx
                                 for i in label2idx[lbl][pointers[lbl]:]]
            client_idxs.extend(rng.sample(all_remaining,
                                          samples_per_client - len(client_idxs)))
        shards_idx.append(client_idxs)

    return [Subset(dataset, idxs) for idxs in shards_idx]


#NEW OUR CONTRIBUTION

# ── C.2 New: Non-IID shards with a random number of classes per client ─────────
from collections import defaultdict
from torch.utils.data import Subset

def create_labelwise_shards_sampled(dataset, K,
                                    min_classes=1, max_classes=50,
                                    sampler='uniform', poisson_lambda=5,
                                    allocation='equal', dirichlet_alpha=1.0,
                                    seed=42):
    """
    Build K disjoint subsets where each client:
      - samples n_classes ~ (uniform[min,max] OR 1+Poisson(lambda))
      - selects those classes (without replacement)
      - receives `target` examples distributed among the chosen classes
        according to `allocation` (equal or dirichlet proportions)
    Guarantees: no example is duplicated across clients and every example assigned.

    Args:
      dataset: torch Dataset (train_dataset)
      K: number of clients
      min_classes, max_classes: bounds for sampled number of classes per client
      sampler: 'uniform' or 'poisson'
      poisson_lambda: lambda for Poisson sampler
      allocation: 'equal' | 'dirichlet' | 'random' (random proportional)
      dirichlet_alpha: alpha parameter for Dirichlet (if allocation == 'dirichlet')
      seed: RNG seed for reproducibility

    Returns:
      list_of_subsets: list of torch.utils.data.Subset objects length K
    """
    # --- Build per-label index pools (deques for efficient popleft) ---
    label2idx = defaultdict(list)
    for idx, (_, lbl) in enumerate(dataset):
        label2idx[lbl].append(idx)
    # shuffle each label's pool reproducibly
    rng_py = random.Random(seed)
    for lbl in label2idx:
        rng_py.shuffle(label2idx[lbl])
    label_deques = {lbl: deque(label2idx[lbl]) for lbl in label2idx}
    labels = list(label_deques.keys())
    n_labels_total = len(labels)

    # --- compute per-client target sizes (balanced remainder) ---
    N = len(dataset)
    base = N // K
    remainder = N % K
    target_sizes = [base + (1 if i < remainder else 0) for i in range(K)]

    # helper: sample number of classes
    def sample_n_classes_local():
        if sampler == 'uniform':
            return rng_py.randint(min_classes, min(max_classes, n_labels_total))
        elif sampler == 'poisson':
            # use numpy's generator seeded with rng_py for reproducibility
            seed_local = rng_py.randint(0, 2**31 - 1)
            n = int(np.random.default_rng(seed_local).poisson(lam=poisson_lambda)) + 1
            return max(min_classes, min(n, min(max_classes, n_labels_total)))
        else:
            return rng_py.randint(min_classes, min(max_classes, n_labels_total))

    # helper: allocate counts across chosen classes given target and allocation scheme
    def allocate_counts(target, n_chosen):
        if n_chosen <= 0:
            return []
        if allocation == 'equal':
            base_share = target // n_chosen
            rem = target % n_chosen
            alloc = [base_share + (1 if i < rem else 0) for i in range(n_chosen)]
            return alloc
        elif allocation == 'dirichlet':
            # sample proportions from Dirichlet(alpha)
            alpha = np.ones(n_chosen) * float(dirichlet_alpha)
            prop = np.random.default_rng(rng_py.randint(0, 2**31-1)).dirichlet(alpha)
            raw = prop * target
            # convert to integer allocation preserving sum==target
            floored = np.floor(raw).astype(int).tolist()
            leftover = target - sum(floored)
            # distribute leftover to largest fractional parts
            fracs = raw - np.floor(raw)
            order = np.argsort(fracs)[::-1]
            for j in range(leftover):
                floored[order[j]] += 1
            return floored
        else:  # 'random' : choose random integer splits (via multinomial)
            rng_seed = rng_py.randint(0, 2**31 - 1)
            props = np.random.default_rng(rng_seed).multinomial(target, [1.0 / n_chosen] * n_chosen)
            return props.tolist()

    # Prepare result list and a randomized client order to mitigate ordering bias
    client_indices = [[] for _ in range(K)]
    client_order = list(range(K))
    rng_py.shuffle(client_order)  # process clients in random order (deterministic from seed)

    # For speed: keep a small lookup of remaining counts per label
    remaining_per_label = {lbl: len(label_deques[lbl]) for lbl in labels}

    for client_id in client_order:
        target = target_sizes[client_id]
        # sample how many classes this client *wants*
        n_classes = sample_n_classes_local()
        n_classes = min(n_classes, n_labels_total)  # safety

        # choose the classes for this client (without replacement)
        # but prefer classes that still have remaining samples: sample from labels weighted by availability
        available_labels = [lbl for lbl in labels if remaining_per_label.get(lbl, 0) > 0]
        if len(available_labels) == 0:
            # no remaining samples anywhere — extremely unlikely
            break

        # If available_labels < n_classes, we will only choose those available; rest will be filled later.
        if len(available_labels) <= n_classes:
            chosen_labels = available_labels[:]
            rng_py.shuffle(chosen_labels)
        else:
            # sample without replacement among available labels
            # use rng_py.sample for reproducibility
            chosen_labels = rng_py.sample(available_labels, k=n_classes)

        # compute desired allocation across chosen_labels
        alloc = allocate_counts(target, len(chosen_labels))

        # Try to fulfill allocation from chosen labels, consuming their deques
        client_taken = []
        shortfall = 0
        for lbl, want in zip(chosen_labels, alloc):
            available = remaining_per_label.get(lbl, 0)
            take = min(want, available)
            for _ in range(take):
                client_taken.append(label_deques[lbl].popleft())
            remaining_per_label[lbl] = remaining_per_label.get(lbl, 0) - take
            if take < want:
                shortfall += (want - take)

        # If there is a shortfall, try to fill it from other labels (scan labels by remaining)
        if shortfall > 0:
            # build a list of labels sorted by remaining count (descending) to fill quickly
            refill_labels = sorted(labels, key=lambda x: remaining_per_label.get(x, 0), reverse=True)
            for lbl in refill_labels:
                if shortfall <= 0:
                    break
                available = remaining_per_label.get(lbl, 0)
                if available <= 0:
                    continue
                take = min(available, shortfall)
                for _ in range(take):
                    client_taken.append(label_deques[lbl].popleft())
                remaining_per_label[lbl] -= take
                shortfall -= take

        # Final safety: if still short (very unlikely), allow sampling from any remaining indices with replacement
        if len(client_taken) < target:
            need = target - len(client_taken)
            all_remaining = []
            for lbl in labels:
                all_remaining.extend(list(label_deques[lbl]))
            if len(all_remaining) >= need and len(all_remaining) > 0:
                # take deterministically from the front of remaining pools
                # and advance pointers (pop left)
                taken_now = all_remaining[:need]
                # Pop these indices from deques by label
                taken_count = 0
                for lbl in labels:
                    while taken_count < need and len(label_deques[lbl]) > 0:
                        client_taken.append(label_deques[lbl].popleft())
                        remaining_per_label[lbl] -= 1
                        taken_count += 1
                        if taken_count >= need:
                            break
            else:
                # fallback: sample with replacement from full index range (shouldn't be necessary)
                rng2 = random.Random(rng_py.randint(0, 2**31 - 1))
                while len(client_taken) < target:
                    client_taken.append(rng2.choice(range(N)))

        # Ensure exact target
        if len(client_taken) > target:
            client_taken = client_taken[:target]
        elif len(client_taken) < target:
            # pad (should not happen) with random indices not yet used if possible
            all_remaining = []
            for lbl in labels:
                all_remaining.extend(list(label_deques[lbl]))
            if len(all_remaining) > 0:
                client_taken += all_remaining[:(target - len(client_taken))]
                # pop them
                taken_rem = target - len(client_taken)
                popped = 0
                for lbl in labels:
                    while popped < taken_rem and len(label_deques[lbl]) > 0:
                        label_deques[lbl].popleft()
                        remaining_per_label[lbl] -= 1
                        popped += 1
                        if popped >= taken_rem:
                            break
            else:
                # absolute last resort: sample from full dataset with replacement
                rng2 = random.Random(rng_py.randint(0, 2**31 - 1))
                while len(client_taken) < target:
                    client_taken.append(rng2.choice(range(N)))

        client_indices[client_id] = client_taken

    # Final check: every example should be assigned exactly once
    all_assigned = [i for lst in client_indices for i in lst]
    if len(all_assigned) != len(set(all_assigned)):
        # Debug info if something went wrong
        dup_count = len(all_assigned) - len(set(all_assigned))
        print(f"[Warning] {dup_count} duplicates detected in assignment (unexpected).")
    if sum(len(lst) for lst in client_indices) != N:
        # Some items may remain unassigned if remainder was mis-handled; append them to last clients
        remaining = []
        for lbl in labels:
            remaining.extend(list(label_deques[lbl]))
        if remaining:
            # distribute remaining to clients with available capacity
            for idx in remaining:
                # find first client with room
                for cid in range(K):
                    if len(client_indices[cid]) < target_sizes[cid]:
                        client_indices[cid].append(idx)
                        break

    # Convert to Subsets
    subsets = [Subset(dataset, idxs) for idxs in client_indices]
    return subsets

# ── Utility: number of unique classes in a Subset ─────────────────────────────────
def subset_num_classes(subset):
    labs = set()
    # subset is a torch.utils.data.Subset pointing to original dataset
    base_ds = subset.dataset
    for idx in subset.indices:
        _, lbl = base_ds[idx]
        labs.add(lbl)
    return len(labs)
# Out:
# test_loader already defined in scope.

# %%
# existing:
K = 100
base = train_size // K
sizes = [base] * (K - 1) + [train_size - base * (K - 1)]
##iid_shards = random_split(train_dataset, sizes, generator=torch.Generator().manual_seed(seed))

##shardings = {'iid': iid_shards}
shardings = {}

# Add old non_iid_Nc variants if you want to keep them
Nc_list = [1, 5, 10, 50]
"""for Nc in Nc_list:
    shardings[f'non_iid_{Nc}'] = create_labelwise_shards(train_dataset, K, Nc, seed)"""

# Add new random-classes variants:
shardings['sampled_uniform'] = create_labelwise_shards_sampled(
    train_dataset, K,
    min_classes=1, max_classes=50,
    sampler='uniform', allocation='equal', seed=42
)
print(f'sharding keys after sampled_uniform: {shardings.keys()}')
# Out:
# sharding keys after sampled_uniform: dict_keys(['sampled_uniform'])

# %%
# run after creating 'subsets' (e.g. shards = shardings['non_iid_random_uniform_1_50'])
subsets = shardings['sampled_uniform']  # or call the function directly
K_check = len(subsets)
samples_per_client = len(subsets[0].indices)

# 1) same size per client
sizes = [len(s.indices) for s in subsets]
print("sizes: min, max, unique counts:", min(sizes), max(sizes), set(sizes))

# 2) no duplicates across clients and coverage
all_idxs = [i for s in subsets for i in s.indices]
total_assigned = len(all_idxs)
unique_assigned = len(set(all_idxs))
print("total_assigned:", total_assigned, "unique_assigned:", unique_assigned)

if unique_assigned != total_assigned:
    print("WARNING: some indices are duplicated across clients.")
else:
    print("OK: no duplicated indices across clients.")

# 3) full coverage (only true if K * samples_per_client == len(dataset))
N = len(train_dataset)
print("dataset size N:", N, "K*samples_per_client:", K_check * samples_per_client)
if K_check * samples_per_client == N:
    print("OK: every example is assigned exactly once.")
else:
    print("Note: not all examples were assigned (this is expected if N not divisible by K).")

# 4) classes per client distribution
def subset_num_classes(sub):
    base = sub.dataset
    labs = set(base[idx][1] for idx in sub.indices)
    return len(labs)

classes_per_client = [subset_num_classes(s) for s in subsets]
print("classes per client: min, max, mean:", min(classes_per_client), max(classes_per_client), sum(classes_per_client)/len(classes_per_client))
# Out:
# sizes: min, max, unique counts: 450 450 {450}
# total_assigned: 45000 unique_assigned: 45000
# OK: no duplicated indices across clients.
# dataset size N: 45000 K*samples_per_client: 45000
# OK: every example is assigned exactly once.
# classes per client: min, max, mean: 2 49 24.38

# %%
# Helper: compute unique classes per subset (client)
import pandas as pd

def subset_num_classes(subset, dataset):
    labs = set(dataset[idx][1] for idx in subset.indices)
    return len(labs)

# Compute
K = len(subsets)
classes_per_client = [subset_num_classes(s, train_dataset) for s in subsets]

# DataFrame for convenience
df = pd.DataFrame({
    'client_id': np.arange(K),
    'unique_classes': classes_per_client
})
df.to_csv("classes_per_client.csv", index=False)
print("Saved classes_per_client.csv (client_id, unique_classes)")

# 1) Bar plot (clients on x)
plt.figure(figsize=(14,4))
plt.bar(df['client_id'], df['unique_classes'])
plt.xlabel("Client id")
plt.ylabel("Number of unique classes")
plt.title("Unique classes per client (bar)")
plt.tight_layout()
plt.savefig("classes_per_client_bar.png")
plt.show()

# 2) Histogram (distribution)
max_classes = max(classes_per_client)
bins = range(0, max_classes+2)  # integer bins
plt.figure(figsize=(8,4))
plt.hist(classes_per_client, bins=bins, align='left', rwidth=0.8)
plt.xticks(bins)
plt.xlabel("Unique classes per client")
plt.ylabel("Number of clients")
plt.title("Histogram: unique classes per client")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig("classes_per_client_hist.png")
plt.show()

# 3) CDF (cumulative distribution)
vals_sorted = np.sort(classes_per_client)
cdf = np.arange(1, K+1) / K
plt.figure(figsize=(8,4))
plt.step(vals_sorted, cdf, where='post')
plt.xlabel("Unique classes per client")
plt.ylabel("Cumulative fraction of clients")
plt.title("CDF: clients vs unique classes")
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig("classes_per_client_cdf.png")
plt.show()

# Quick stats
print("min, max, mean, median, std:", np.min(classes_per_client),
      np.max(classes_per_client), np.mean(classes_per_client),
      np.median(classes_per_client), np.std(classes_per_client))

# Optional: top clients with most classes
top = df.sort_values('unique_classes', ascending=False).head(10)
print("\nTop 10 clients by number of unique classes:\n", top.to_string(index=False))
# Out:
# Saved classes_per_client.csv (client_id, unique_classes)
# min, max, mean, median, std: 2 49 24.38 23.0 13.898762534844606
#
# Top 10 clients by number of unique classes:
#   client_id  unique_classes
#          3              49
#         64              49
#         98              49
#         12              47
#         93              47
#         72              47
#         33              47
#         71              46
#         51              46
#         82              46

# %%
# parte aggiunta
# === Diversity utilities (Nc + entropy + JS divergence) ===
from collections import Counter
from scipy.spatial.distance import jensenshannon
import numpy as np
import math

NUM_CLASSES = 100  # number of classes in CIFAR-100

def client_class_histograms(shards, dataset, num_classes=NUM_CLASSES):
    """
    Returns a (K, C) numpy array where each row is the histogram of class counts
    for one client: K clients, C classes.
    """
    hists = []
    for sub in shards:
        # Collect labels by indexing the original dataset (dataset[idx][1] yields label)
        labels = [dataset[idx][1] for idx in sub.indices]
        # Count occurrences per class
        cnt = Counter(labels)
        # Initialize zero histogram of length C
        hist = np.zeros(num_classes, dtype=np.int64)
        # Fill histogram with counts for classes present in this subset
        for c, n in cnt.items():
            hist[c] = n
        hists.append(hist)
    # stack into shape (K, C)
    return np.stack(hists, axis=0)


def entropy_from_hist(hist):
    """
    Compute the Shannon entropy of the class distribution represented by `hist`.
    H = - sum_k p_k * log(p_k), where p_k = hist[k] / sum(hist).
    Uses natural logarithm (base e). Returns 0.0 if the histogram is empty.
    """
    n = hist.sum()
    if n == 0:
        # no samples => define entropy as 0
        return 0.0
    # normalized class probabilities
    p = hist / n
    # keep only positive probabilities to avoid log(0)
    p = p[p > 0]
    # compute and return entropy using the natural log (float)
    return float(-np.sum(p * np.log(p)))

# ---- Jensen-Shannon divergence ----

def js_distance_matrix(hists):
    """Compute pairwise JS divergence matrix on normalized histograms"""
    rows = hists.sum(axis=1, keepdims=True)
    rows[rows==0] = 1.0
    P = hists / rows
    K = P.shape[0]
    D = np.zeros((K, K))
    for i in range(K):
        for j in range(i+1, K):
            d = jensenshannon(P[i], P[j])
            D[i,j] = D[j,i] = d
    return D


def diversity_scores_from_hists(hists, lam=0.7):
    """
    Compute per-client diversity scores by combining:
      - Structural diversity: number of unique classes present (Nc)
      - Distributional diversity: entropy of class distribution (H)

    Formula per client:
        D_i = lam * (Nc / C) + (1 - lam) * (H / log(C))

    where:
      - Nc  = number of distinct classes for client i (integer)
      - H   = entropy of the class distribution for client i (natural-log entropy)
      - C   = total number of classes (num columns in hists)
      - lam = weight in [0,1] balancing Nc vs entropy (lam=1 uses only Nc; lam=0 uses only entropy)

     To account for inter-client differences, we also compute the
    Jensen–Shannon (JS) divergence between clients and combine it with D_i:

        Final score = alpha * D_i + (1 - alpha) * JS_i

    where:
      - alpha     = mixing coefficient (0 = only JS, 1 = only D_i)
      - JS_i = mean JS divergence of client i from others


    Returns:
      scores_combined : numpy array shape (K,)  -- array of final diversity scores in [0,1]
      Nc     : numpy array shape (K,)  -- array, number of classes per client (int)
      Hs     : numpy array shape (K,)  -- array, entropy per client (float)
    """

    K, C = hists.shape

    # Count number of classes with at least one sample per client (array of number of classes)
    Nc = (hists > 0).sum(axis=1)

    # Compute entropy per client (array of entropies)
    Hs = np.array([entropy_from_hist(h) for h in hists], dtype=np.float64)

    # Normalize Nc and Hs to [0,1]-like ranges to get comparably scaled terms
    #   Nc/C  → fraction of possible classes present (in [0,1])
    #   Hs/log(C) → entropy scaled by maximum possible entropy (maximum entropy for C classes (uniform) is log(C))
    denom = np.log(C) if C > 1 else 1.0  # stability for C==1: protect division by log(C):
    scores = lam * (Nc / C) + (1 - lam) * (Hs / denom)

    # Calculate JS distance matrix
    D = js_distance_matrix(hists)   ## shape (K, K)

    # For each client, compute the average distance from all the others (js_scores is an array of mean distances)
    js_scores = D.mean(axis=1)      # (K,)

    # Normalize in [0, 1]
    js_scores = js_scores / js_scores.max()

    # Blend intra-client diversity and inter-client dissimilarity
    alpha = 0  # 0 = only JS_i, 1 = only D_i, 0.5 D_i + JS
    scores_combined = alpha * scores + (1 - alpha) * js_scores

    # Return final scores, ensuring float64 precision
    return scores_combined.astype(np.float64), Nc, Hs

    # This score favors clients that either have many different classes (Nc large) or have balanced class distributions (H large), depending on lam
    # Normalization makes the two terms comparable despite different ranges/units

# %%
# === Client Selection Utilities ===

from sklearn.cluster import KMeans
import numpy as np
from scipy.spatial.distance import cdist

# ---- Weighted Selection (Nc + entropy + JS distance) ----
def sample_clients_diversity_weighted(D, m, rng, eps=1e-2, mix_uniform=0.3):
    """
    Sample m clients (without replacement) from K clients using a probability
    distribution biased by diversity scores D.

    Args:
      D          : array-like shape (K,)   -- diversity scores per client
      m          : int                    -- number of clients to select in this round
      rng        : numpy.random.Generator -- RNG used for reproducible sampling
      eps        : float                  -- small positive floor added to weights to avoid zeros
      mix_uniform: float in [0,1]         -- fraction of uniform exploration mass

    Returns:
      selected_indices : list of ints length m -- chosen client indices
      p                : ndarray shape (K,)     -- final probability vector summing to 1
    """
    import numpy as np

    # convert D to numpy array of floats and get K
    D = np.asarray(D, dtype=np.float64)
    K = D.shape[0]

    assert m <= K, "m must be <= K when sampling without replacement"

    # Normalize D into [0, 1] (small epsilon avoids division by zero if D is constant)
    Dn = (D - D.min()) / (D.max() - D.min() + 1e-12)

    # Use normalized D directly as weights (add epsilon floor)
    w_div = Dn + eps

    # Convert weights to a probability distribution
    p_div = w_div / w_div.sum()

    # Uniform distribution for exploration
    p_uni = np.ones(K, dtype=np.float64) / K

    # Mix diversity-driven distribution with uniform exploration
    p = (1.0 - mix_uniform) * p_div + mix_uniform * p_uni

    # Final normalization (numerical safety)
    p = p / p.sum()

    # Sample m clients without replacement according to final probabilities p
    selected = rng.choice(K, size=m, replace=False, p=p)

    return selected.tolist(), p

# ---- KMeans clustering on histograms ----
def kmeans_cluster_clients(hists, n_clusters=10, random_state=0):
    """
    hists: (K, C) raw counts per client
    returns: cluster assignments (K,), and KMeans object
    """
    rows = hists.sum(axis=1, keepdims=True)
    rows[rows==0] = 1.0
    p = hists / rows
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state, n_init=10)
    assigns = kmeans.fit_predict(p)
    return assigns, kmeans

def kmeans_selection(assigns, m, rng=np.random.default_rng()):
    """
    Select up to one (or more) client per cluster, round-robin-ish,
    ensuring coverage of different clusters.
    """
    clusters = {}
    for idx, c in enumerate(assigns):
        clusters.setdefault(c, []).append(idx)
    for c in clusters:
        rng.shuffle(clusters[c])
    selected=[]
    cluster_ids = list(clusters.keys())
    i=0
    while len(selected) < m and len(cluster_ids)>0:
        c = cluster_ids[i % len(cluster_ids)]
        if clusters[c]:
            sel = clusters[c].pop()
            selected.append(sel)
        else:
            cluster_ids.remove(c)
            i -= 1
        i += 1
    return selected

# ---- MMR selection ----
def mmr_selection(hists, m, lambda_val=0.5, relevance=None):
    """
    hists: (K, C) normalized rows or embeddings
    lambda_val: tradeoff between relevance (score) and diversity
    relevance: optional array of relevance scores, else fallback to sum
    """
    rows = hists.sum(axis=1, keepdims=True)
    rows[rows==0] = 1.0
    X = hists / rows

    if relevance is None:
        rel = X.sum(axis=1)
    else:
        rel = relevance

    D = cdist(X, X, metric='cosine')
    selected = []
    first = np.argmax(rel)
    selected.append(int(first))
    candidates = set(range(X.shape[0])) - {first}
    while len(selected) < m and candidates:
        mmr_scores = {}
        for c in candidates:
            div = np.min(D[c, selected])
            mmr_scores[c] = lambda_val * rel[c] + (1 - lambda_val) * div
        nxt = max(mmr_scores, key=mmr_scores.get)
        selected.append(int(nxt))
        candidates.remove(nxt)
    return selected

# ---- K-center (core-set greedy) selection ----
def kcenter_greedy(hists, m):
    rows = hists.sum(axis=1, keepdims=True)
    rows[rows==0] = 1.0
    X = hists / rows
    D = cdist(X, X, metric='euclidean')
    selected = [np.random.randint(0, X.shape[0])]
    dist_to_selected = D[:, selected].min(axis=1)
    while len(selected) < m:
        idx = np.argmax(dist_to_selected)
        selected.append(int(idx))
        dist_to_selected = np.minimum(dist_to_selected, D[:, idx])
    return selected

# %%
# ── D. Model Definition ─────────────────────────────────────────────────────────
class LELeNetCIFAR(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=5, padding=2)
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=5, padding=2)
        self.pool2 = nn.MaxPool2d(2)
        self.fc1   = nn.Linear(64*8*8, 384)
        self.fc2   = nn.Linear(384, 192)
        self.fc3   = nn.Linear(192, 100)
    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x)); x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
# ── E. Utilities: Train/Eval & Checkpointing ────────────────────────────────────
def train_one_epoch(model, optimizer, criterion, loader):
    model.train()
    running_loss = correct = total = 0
    for imgs, lbls in loader:
        imgs, lbls = imgs.to(device), lbls.to(device)
        optimizer.zero_grad()
        out = model(imgs)
        loss = criterion(out, lbls)
        loss.backward(); optimizer.step()
        running_loss += loss.item()*imgs.size(0)
        correct += out.argmax(1).eq(lbls).sum().item()
        total += lbls.size(0)
    return running_loss/total, correct/total

def eval_model(model, criterion, loader):
    model.eval()
    running_loss = correct = total = 0
    with torch.no_grad():
        for imgs, lbls in loader:
            imgs, lbls = imgs.to(device), lbls.to(device)
            out = model(imgs); loss = criterion(out, lbls)
            running_loss += loss.item()*imgs.size(0)
            correct += out.argmax(1).eq(lbls).sum().item()
            total += lbls.size(0)
    return running_loss/total, correct/total


def sample_clients_dirichlet(K, m, gamma, rng):
    """
    Sample m out of K client indices, with probabilities:
      • uniform if gamma == 'uniform'
      • drawn from Dirichlet([gamma]*K) otherwise.
    Returns:
      selected: list of m client indices
      p:        length-K numpy array of sampling probs (sums to 1)
    """
    if gamma == 'uniform':
        p = np.ones(K) / K
    else:
        alpha = np.ones(K) * gamma
        p     = rng.dirichlet(alpha)
    selected = rng.choice(K, size=m, replace=False, p=p)
    return selected.tolist(), p

# %%
# ── Configuration Summary & Utilities for FedAvg ──────────────────────────────

import os, sys, platform, time
import torch
import numpy as np
import random
from torch.utils.tensorboard import SummaryWriter



# 3) Hyperparameters
K, C = 100, 0.1
BS, BS_VAL = 128, 256
LR, WD = 0.01, 1e-4
J0, R0   = 4, 1000
budget   = J0 * R0
J_list   = [4, 8, 16]



# 1) Define and instantiate your TensorBoard writer
log_dir = f"./logs/FedAvg_lr{LR}_wd{WD}_bs{BS}"
tb_writer = SummaryWriter(log_dir=log_dir)

# 2) Summary utility
def summarize_run(cfg, client_loaders, test_loader, writer=None):
    """
    Print and log summary for a FedAvg run.
    """
    ts = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
    print(f"\n========== FEDAVG RUN SUMMARY ({ts}) ==========")
    # Hyperparameters
    for key in ['lr','weight_decay','batch_size','K','C','J','ROUNDS']:
        print(f"    • {key}: {cfg[key]}")
    # Data info
    num_clients  = len(client_loaders)
    shard_size   = len(client_loaders[0].dataset)
    test_samples = len(test_loader.dataset)
    print(f"    • clients (K): {num_clients}, shard size: {shard_size}")
    print(f"    • test samples: {test_samples}, batch size: {cfg['batch_size']}")
    # Log to TensorBoard
    if writer:
        for key in ['lr','weight_decay','batch_size','K','C','J','ROUNDS']:
            writer.add_text(f'RunInfo/{key}', str(cfg[key]), 0)

# 3) Checkpoint utility
ckpt_dir = './checkpoints'
os.makedirs(ckpt_dir, exist_ok=True)


# ── Example Usage ────────────────────────────────────────────────────────────────

cfg = {
    'lr':           LR,
    'weight_decay': WD,
    'batch_size':   BS,
    'K':            K,
    'C':            C,
    'J0':            J0,
    'ROUNDS':       R0

}

# %%
# ── A. Mount Google Drive ─────────────────────────────────────────────────────
from google.colab import drive
import os

drive.mount('/content/drive')
# Point to a folder inside your Drive for persistent checkpoints
CKPT_DIR = '/content/drive/MyDrive/Nc_entropy_no_alpha_t/checkpoints'
os.makedirs(CKPT_DIR, exist_ok=True)




# Set this to True to resume from the last checkpoint; False to start from scratch
RESUME = True



# 3) Hyperparameters
K, C = 100, 0.1
BS, BS_VAL = 128, 256
LR, WD = 0.01, 1e-4
J0, R0   = 4, 1000
budget   = J0 * R0
J_list   = [4, 8, 16]

# 4) Transforms & Data
transform_train = T.Compose([
    T.RandomCrop(32, 4), T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize((0.5071,0.4867,0.4408),(0.2675,0.2565,0.2761)),
])
transform_test = T.Compose([
    T.ToTensor(),
    T.Normalize((0.5071,0.4867,0.4408),(0.2675,0.2565,0.2761)),
])

full_train = torchvision.datasets.CIFAR100(
    './data', train=True, download=True, transform=transform_train
)
val_size   = 5000
train_size = len(full_train) - val_size
train_dataset, val_dataset = random_split(
    full_train, [train_size, val_size],
    generator=torch.Generator().manual_seed(seed)
)
val_loader = DataLoader(val_dataset, batch_size=BS_VAL, shuffle=False, num_workers=2)

test_dataset = torchvision.datasets.CIFAR100(
    './data', train=False, download=True, transform=transform_test
)
test_loader = DataLoader(test_dataset, batch_size=BS_VAL, shuffle=False, num_workers=2)



# ── Instantiate TensorBoard writer ──────────────────────────────────────────────
from torch.utils.tensorboard import SummaryWriter
log_dir   = f"./logs/FedAvg_lr{LR}_wd{WD}_bs{BS}"
tb_writer = SummaryWriter(log_dir=log_dir)



# ── B. CSV Logging Setup ────────────────────────────────────────────────────────
import csv, os
#csv_path = './fedavg_results.csv'
csv_path = '/content/drive/MyDrive/Nc_entropy_no_alpha_t/Nc_entropy_JS_no_alpha_t_fedavg_results.csv'
if not os.path.exists(csv_path):
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([
            'name', 'round', 'round_time',
            'local_mean', 'local_std',
            'val_loss', 'val_acc',
            'test_loss', 'test_acc'
        ])

# Before your FedAvg loop: Instantiate the global model, loss, and client loaders once


# 6) Build all shardings
base = train_size // K
sizes = [base]*(K-1) + [train_size-base*(K-1)]
##iid_shards = random_split(train_dataset, sizes, generator=torch.Generator().manual_seed(seed))

Nc_list   = [1, 5, 10, 50]
##shardings = {'iid': iid_shards}
shardings = {}

"""for Nc in Nc_list:
    shardings[f'non_iid_{Nc}'] = create_labelwise_shards(
        train_dataset, K, Nc, seed
    )"""

# Add new random-classes variants:
shardings['sampled_uniform'] = create_labelwise_shards_sampled(
    train_dataset, K,
    min_classes=1, max_classes=50,
    sampler='uniform', allocation='equal', seed=42
)
print(f'sharding keys after sampled_uniform: {shardings.keys()}')

cfg = {'lr': LR, 'weight_decay': WD, 'batch_size': BS, 'K': K, 'C': C}

rng = np.random.default_rng(seed)

# ── C. FedAvg Training Loop ─────────────────────────────────────────────────────
# ── F. FedAvg Experiment Loop with Drive Checkpoints ──────────────────────────
# Assumes `shardings`, `J_list`, `budget`, `load_checkpoint`, `save_checkpoint`, etc. are defined

# ── D: Training Loop ────────────────────────────────────────────────────────────
all_results = {}

"""for shard_key, shards in shardings.items():
    client_loaders = [
        DataLoader(shards[i], batch_size=BS, shuffle=True, num_workers=2)
        for i in range(K)
    ]"""
print(f"sharding keys: {shardings.keys()}")
shard_keys_to_run = ['sampled_uniform']  # or ['non_iid_random_poisson_1_20'], or both

for shard_key in shard_keys_to_run:
    shards = shardings[shard_key]
    client_loaders = [
        DataLoader(shards[i], batch_size=BS, shuffle=True, num_workers=2)
        for i in range(K)
    ]

    # parte aggiunta
    # Compute diversity scores for the current clients
    hists = client_class_histograms(shards, train_dataset, num_classes=100)

    # Calculate different measures of diversity from the histograms
    # D_scores: combined diversity score (a weighted mix of number of classes per client and entropy, with lam controlling the weight)
    # D_Nc: number of distinct classes per client
    # D_H: entropy of the class distribution for each client
    D_scores, D_Nc, D_H = diversity_scores_from_hists(hists, lam=0.5)

    # Print summary statistics (min, mean, max) for each metric across clients
    print(f"[Diversity] Nc min/mean/max = {D_Nc.min()}/{D_Nc.mean():.2f}/{D_Nc.max()}")
    print(f"[Diversity] H  min/mean/max = {D_H.min():.2f}/{D_H.mean():.2f}/{D_H.max():.2f}")
    print(f"[Diversity] D  min/mean/max = {D_scores.min():.3f}/{D_scores.mean():.3f}/{D_scores.max():.3f}")

    for J in J_list:
        ROUNDS_scaled = budget // J
        cfg.update({'J': J, 'ROUNDS': ROUNDS_scaled})
        summarize_run(cfg, client_loaders, test_loader, writer=tb_writer)

        # Initialize model & optimizer, then resume if any
        model     = LELeNetCIFAR().to(device)
        optimizer = optim.SGD(model.parameters(), lr=LR, momentum=0.9, weight_decay=WD)
        criterion = nn.CrossEntropyLoss()
        start_round = load_checkpoint(
            model, optimizer,
            ckpt_dir=CKPT_DIR,
            shard_key=shard_key, J=J,
            resume=RESUME
        )

        acc_hist = []
        print(f"[{shard_key}|J={J}] Starting from round {start_round}/{ROUNDS_scaled}")

        for rnd in range(start_round, ROUNDS_scaled + 1):
            m = max(1, int(C * K))
            #selected, _ = sample_clients_dirichlet(K, m, gamma='uniform', rng=rng)
            round_start = time.time()

            """ ----- CHANGE HERE TO USE DIFFERENT CLIENT SELECTION METHODS ----- """
            ## ---- DIVERSITY WEIGHTED SELECTION ----
            selected, p = sample_clients_diversity_weighted(
                D_scores, m, rng=rng, eps=0.01, mix_uniform=0.30 )
            client_sel = "Nc_entropy_JS"

            ## ---- K-MEANS CLIENT SELECTION ----
            ##assigns, _ = kmeans_cluster_clients(hists, n_clusters=10)
            ##selected = kmeans_selection(assigns, m)
            ##client_sel = "k_means"

            ## ---- MMR CLIENT SELECTION ----
            ##selected_clients = mmr_selection(hists, m, lambda_val=0.5)
            ##client_sel = "mmr"

            ## ---- K-CENTER CLIENT SELECTION ----
            ##selected_clients = kcenter_greedy(hists, m)
            ##client_sel = "k_center"

            # Local updates
            local_accuracies = []
            local_states, sizes = [], []
            for cid in selected:
                cm    = copy.deepcopy(model)
                opt_c = optim.SGD(cm.parameters(), lr=LR, momentum=0.9, weight_decay=WD)
                for _ in range(J):
                    train_loss, train_acc = train_one_epoch(cm, opt_c, criterion, client_loaders[cid])
                local_states.append(cm.state_dict())
                sizes.append(len(shards[cid]))
                local_accuracies.append(train_acc)


            # Compute local mean & std
            local_mean = np.mean(local_accuracies)
            local_std  = np.std(local_accuracies)

            # Aggregate
            total = sum(sizes)
            new_st = {
                k: sum((sizes[i] / total) * local_states[i][k] for i in range(len(sizes)))
                for k in model.state_dict()
            }
            model.load_state_dict(new_st)

            # Eval
            _, val_acc = eval_model(model, criterion, val_loader)
            acc_hist.append(val_acc)

            # 4) Evaluation
            val_loss, val_acc   = eval_model(model, criterion, val_loader)
            test_loss, test_acc = eval_model(model, criterion, test_loader)
            acc_hist.append(test_acc)

            # 5) Timing
            round_time = time.time() - round_start



            # Logging
            # 6) CSV Logging
            with open(csv_path, 'a', newline='') as f:
                csv.writer(f).writerow([
                    f"{client_sel}_no alpha_t", rnd,  # f"2_{shard_key}_J{J}_{client_sel}"
                    f"{round_time:.2f}",
                    f"{local_mean:.4f}", f"{local_std:.4f}",
                    f"{val_loss:.4f}", f"{val_acc:.4f}",
                    f"{test_loss:.4f}", f"{test_acc:.4f}"
                ])

            # 7) TensorBoard Logging
            tb_writer.add_scalar(f"{shard_key}/J{J}_round_time", round_time, rnd)
            tb_writer.add_scalar(f"{shard_key}/J{J}_local_acc_mean", local_mean, rnd)
            tb_writer.add_scalar(f"{shard_key}/J{J}_local_acc_std",  local_std,  rnd)
            tb_writer.add_scalar(f"{shard_key}/J{J}_val_loss",       val_loss,    rnd)
            tb_writer.add_scalar(f"{shard_key}/J{J}_val_acc",        val_acc,     rnd)
            tb_writer.add_scalar(f"{shard_key}/J{J}_test_loss",      test_loss,   rnd)
            tb_writer.add_scalar(f"{shard_key}/J{J}_test_acc",       test_acc,    rnd)

            # 8) Print per-round summary
            print(
                f"[{shard_key} | J={J}] Round {rnd}/{ROUNDS_scaled} "
                f"Time={round_time:.1f}s | "
                f"Local Acc={local_mean:.3f}±{local_std:.3f} | "
                f"Val Acc={val_acc:.3f} | Test Acc={test_acc:.3f}"
            )



            # Checkpoint every 20 rounds (or at first)
            if rnd == start_round or rnd % 20 == 0:
              # 1) Log a header with the current config and round
              print(f"[{shard_key} | J={J}] Checkpointing at round {rnd}/{ROUNDS_scaled}")

              # 2) Print the latest metrics
              print(f"    → Last Val Acc: {val_acc:.4f} | Last Val Loss: {val_loss:.4f}")
              print(f"    → Last Test Acc: {test_acc:.4f} | Last Test Loss: {test_loss:.4f}")

              # 3) Save the checkpoint
              save_checkpoint(
                  model, optimizer,
                  round_num=rnd,
                  ckpt_dir=CKPT_DIR,
                  shard_key=shard_key, J=J,
                  is_best=False
              )
              print(f"[{shard_key} | J={J}] Checkpoint saved.\n")

        all_results[(shard_key, J)] = np.array(acc_hist)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# sharding keys after sampled_uniform: dict_keys(['sampled_uniform'])
# sharding keys: dict_keys(['sampled_uniform'])
# [Diversity] Nc min/mean/max = 2/24.38/49
# [Diversity] H  min/mean/max = 0.64/2.93/3.89
# [Diversity] D  min/mean/max = 0.826/0.899/1.000
#
# ========== FEDAVG RUN SUMMARY (2025-08-29 17:23:44) ==========
#     • lr: 0.01
#     • weight_decay: 0.0001
#     • batch_size: 128
#     • K: 100
#     • C: 0.1
#     • J: 4
#     • ROUNDS: 2000
#     • clients (K): 100, shard size: 450
#     • test samples: 10000, batch size: 128
# [sampled_uniform|J=4] Starting from round 1/2000
# [sampled_uniform | J=4] Round 1/2000 Time=18.5s | Local Acc=0.180±0.146 | Val Acc=0.011 | Test Acc=0.010
# [sampled_uniform | J=4] Checkpointing at round 1/2000
#     → Last Val Acc: 0.0112 | Last Val Loss: 4.6508
#     → Last Test Acc: 0.0103 | Last Test Loss: 4.6407
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_1.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 2/2000 Time=17.8s | Local Acc=0.137±0.149 | Val Acc=0.011 | Test Acc=0.011
# [sampled_uniform | J=4] Round 3/2000 Time=17.2s | Local Acc=0.120±0.139 | Val Acc=0.016 | Test Acc=0.014
# [sampled_uniform | J=4] Round 4/2000 Time=18.3s | Local Acc=0.172±0.198 | Val Acc=0.010 | Test Acc=0.010
# [sampled_uniform | J=4] Round 5/2000 Time=17.7s | Local Acc=0.088±0.055 | Val Acc=0.010 | Test Acc=0.011
# [sampled_uniform | J=4] Round 6/2000 Time=17.1s | Local Acc=0.118±0.129 | Val Acc=0.013 | Test Acc=0.015
# [sampled_uniform | J=4] Round 7/2000 Time=18.0s | Local Acc=0.120±0.142 | Val Acc=0.010 | Test Acc=0.009
# [sampled_uniform | J=4] Round 8/2000 Time=17.6s | Local Acc=0.137±0.117 | Val Acc=0.012 | Test Acc=0.013
# [sampled_uniform | J=4] Round 9/2000 Time=17.1s | Local Acc=0.286±0.209 | Val Acc=0.026 | Test Acc=0.029
# [sampled_uniform | J=4] Round 10/2000 Time=19.7s | Local Acc=0.140±0.122 | Val Acc=0.025 | Test Acc=0.024
# [sampled_uniform | J=4] Round 11/2000 Time=17.3s | Local Acc=0.272±0.249 | Val Acc=0.032 | Test Acc=0.033
# [sampled_uniform | J=4] Round 12/2000 Time=17.2s | Local Acc=0.205±0.164 | Val Acc=0.024 | Test Acc=0.022
# [sampled_uniform | J=4] Round 13/2000 Time=18.3s | Local Acc=0.167±0.054 | Val Acc=0.027 | Test Acc=0.034
# [sampled_uniform | J=4] Round 14/2000 Time=17.4s | Local Acc=0.332±0.284 | Val Acc=0.031 | Test Acc=0.031
# [sampled_uniform | J=4] Round 15/2000 Time=17.0s | Local Acc=0.186±0.090 | Val Acc=0.039 | Test Acc=0.033
# [sampled_uniform | J=4] Round 16/2000 Time=17.9s | Local Acc=0.246±0.106 | Val Acc=0.031 | Test Acc=0.034
# [sampled_uniform | J=4] Round 17/2000 Time=17.7s | Local Acc=0.280±0.159 | Val Acc=0.029 | Test Acc=0.035
# [sampled_uniform | J=4] Round 18/2000 Time=17.1s | Local Acc=0.263±0.132 | Val Acc=0.043 | Test Acc=0.040
# [sampled_uniform | J=4] Round 19/2000 Time=17.3s | Local Acc=0.260±0.132 | Val Acc=0.024 | Test Acc=0.027
# [sampled_uniform | J=4] Round 20/2000 Time=18.2s | Local Acc=0.240±0.120 | Val Acc=0.039 | Test Acc=0.041
# [sampled_uniform | J=4] Checkpointing at round 20/2000
#     → Last Val Acc: 0.0390 | Last Val Loss: 4.4070
#     → Last Test Acc: 0.0407 | Last Test Loss: 4.3738
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_20.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 21/2000 Time=17.1s | Local Acc=0.273±0.099 | Val Acc=0.032 | Test Acc=0.041
# [sampled_uniform | J=4] Round 22/2000 Time=17.2s | Local Acc=0.267±0.132 | Val Acc=0.047 | Test Acc=0.054
# [sampled_uniform | J=4] Round 23/2000 Time=19.5s | Local Acc=0.286±0.125 | Val Acc=0.046 | Test Acc=0.045
# [sampled_uniform | J=4] Round 24/2000 Time=17.1s | Local Acc=0.400±0.184 | Val Acc=0.030 | Test Acc=0.029
# [sampled_uniform | J=4] Round 25/2000 Time=17.3s | Local Acc=0.254±0.139 | Val Acc=0.029 | Test Acc=0.030
# [sampled_uniform | J=4] Round 26/2000 Time=18.2s | Local Acc=0.259±0.095 | Val Acc=0.044 | Test Acc=0.045
# [sampled_uniform | J=4] Round 27/2000 Time=18.6s | Local Acc=0.321±0.132 | Val Acc=0.041 | Test Acc=0.043
# [sampled_uniform | J=4] Round 28/2000 Time=17.1s | Local Acc=0.306±0.104 | Val Acc=0.042 | Test Acc=0.046
# [sampled_uniform | J=4] Round 29/2000 Time=18.5s | Local Acc=0.350±0.178 | Val Acc=0.053 | Test Acc=0.056
# [sampled_uniform | J=4] Round 30/2000 Time=17.0s | Local Acc=0.249±0.079 | Val Acc=0.046 | Test Acc=0.051
# [sampled_uniform | J=4] Round 31/2000 Time=17.2s | Local Acc=0.314±0.111 | Val Acc=0.062 | Test Acc=0.059
# [sampled_uniform | J=4] Round 32/2000 Time=18.3s | Local Acc=0.289±0.129 | Val Acc=0.052 | Test Acc=0.053
# [sampled_uniform | J=4] Round 33/2000 Time=17.2s | Local Acc=0.322±0.109 | Val Acc=0.052 | Test Acc=0.049
# [sampled_uniform | J=4] Round 34/2000 Time=17.1s | Local Acc=0.392±0.180 | Val Acc=0.060 | Test Acc=0.059
# [sampled_uniform | J=4] Round 35/2000 Time=17.8s | Local Acc=0.252±0.122 | Val Acc=0.051 | Test Acc=0.056
# [sampled_uniform | J=4] Round 36/2000 Time=17.6s | Local Acc=0.319±0.194 | Val Acc=0.056 | Test Acc=0.058
# [sampled_uniform | J=4] Round 37/2000 Time=17.0s | Local Acc=0.297±0.167 | Val Acc=0.045 | Test Acc=0.052
# [sampled_uniform | J=4] Round 38/2000 Time=18.0s | Local Acc=0.408±0.229 | Val Acc=0.048 | Test Acc=0.053
# [sampled_uniform | J=4] Round 39/2000 Time=17.8s | Local Acc=0.347±0.152 | Val Acc=0.068 | Test Acc=0.073
# [sampled_uniform | J=4] Round 40/2000 Time=18.2s | Local Acc=0.303±0.106 | Val Acc=0.036 | Test Acc=0.051
# [sampled_uniform | J=4] Checkpointing at round 40/2000
#     → Last Val Acc: 0.0358 | Last Val Loss: 4.5905
#     → Last Test Acc: 0.0513 | Last Test Loss: 4.3271
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_40.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 41/2000 Time=17.6s | Local Acc=0.276±0.073 | Val Acc=0.066 | Test Acc=0.077
# [sampled_uniform | J=4] Round 42/2000 Time=17.9s | Local Acc=0.336±0.123 | Val Acc=0.061 | Test Acc=0.070
# [sampled_uniform | J=4] Round 43/2000 Time=17.1s | Local Acc=0.312±0.126 | Val Acc=0.073 | Test Acc=0.072
# [sampled_uniform | J=4] Round 44/2000 Time=17.4s | Local Acc=0.347±0.169 | Val Acc=0.059 | Test Acc=0.058
# [sampled_uniform | J=4] Round 45/2000 Time=18.2s | Local Acc=0.396±0.204 | Val Acc=0.070 | Test Acc=0.087
# [sampled_uniform | J=4] Round 46/2000 Time=17.3s | Local Acc=0.302±0.149 | Val Acc=0.074 | Test Acc=0.091
# [sampled_uniform | J=4] Round 47/2000 Time=17.2s | Local Acc=0.371±0.129 | Val Acc=0.079 | Test Acc=0.080
# [sampled_uniform | J=4] Round 48/2000 Time=18.6s | Local Acc=0.368±0.129 | Val Acc=0.086 | Test Acc=0.100
# [sampled_uniform | J=4] Round 49/2000 Time=17.4s | Local Acc=0.377±0.140 | Val Acc=0.063 | Test Acc=0.073
# [sampled_uniform | J=4] Round 50/2000 Time=17.2s | Local Acc=0.302±0.080 | Val Acc=0.064 | Test Acc=0.067
# [sampled_uniform | J=4] Round 51/2000 Time=18.7s | Local Acc=0.359±0.108 | Val Acc=0.074 | Test Acc=0.080
# [sampled_uniform | J=4] Round 52/2000 Time=17.6s | Local Acc=0.494±0.241 | Val Acc=0.079 | Test Acc=0.088
# [sampled_uniform | J=4] Round 53/2000 Time=18.5s | Local Acc=0.339±0.105 | Val Acc=0.067 | Test Acc=0.083
# [sampled_uniform | J=4] Round 54/2000 Time=18.4s | Local Acc=0.381±0.112 | Val Acc=0.067 | Test Acc=0.068
# [sampled_uniform | J=4] Round 55/2000 Time=17.8s | Local Acc=0.412±0.175 | Val Acc=0.069 | Test Acc=0.082
# [sampled_uniform | J=4] Round 56/2000 Time=19.0s | Local Acc=0.395±0.191 | Val Acc=0.069 | Test Acc=0.084
# [sampled_uniform | J=4] Round 57/2000 Time=18.2s | Local Acc=0.346±0.157 | Val Acc=0.070 | Test Acc=0.083
# [sampled_uniform | J=4] Round 58/2000 Time=17.8s | Local Acc=0.433±0.184 | Val Acc=0.075 | Test Acc=0.082
# [sampled_uniform | J=4] Round 59/2000 Time=19.7s | Local Acc=0.412±0.155 | Val Acc=0.071 | Test Acc=0.091
# [sampled_uniform | J=4] Round 60/2000 Time=18.3s | Local Acc=0.381±0.105 | Val Acc=0.084 | Test Acc=0.083
# [sampled_uniform | J=4] Checkpointing at round 60/2000
#     → Last Val Acc: 0.0842 | Last Val Loss: 4.0469
#     → Last Test Acc: 0.0834 | Last Test Loss: 4.0107
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_60.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 61/2000 Time=18.2s | Local Acc=0.359±0.099 | Val Acc=0.081 | Test Acc=0.097
# [sampled_uniform | J=4] Round 62/2000 Time=19.5s | Local Acc=0.371±0.116 | Val Acc=0.086 | Test Acc=0.096
# [sampled_uniform | J=4] Round 63/2000 Time=18.7s | Local Acc=0.381±0.143 | Val Acc=0.082 | Test Acc=0.098
# [sampled_uniform | J=4] Round 64/2000 Time=19.5s | Local Acc=0.352±0.113 | Val Acc=0.082 | Test Acc=0.100
# [sampled_uniform | J=4] Round 65/2000 Time=19.4s | Local Acc=0.513±0.161 | Val Acc=0.083 | Test Acc=0.106
# [sampled_uniform | J=4] Round 66/2000 Time=18.7s | Local Acc=0.442±0.139 | Val Acc=0.099 | Test Acc=0.105
# [sampled_uniform | J=4] Round 67/2000 Time=18.6s | Local Acc=0.504±0.164 | Val Acc=0.101 | Test Acc=0.105
# [sampled_uniform | J=4] Round 68/2000 Time=17.8s | Local Acc=0.417±0.126 | Val Acc=0.079 | Test Acc=0.095
# [sampled_uniform | J=4] Round 69/2000 Time=19.4s | Local Acc=0.497±0.190 | Val Acc=0.079 | Test Acc=0.093
# [sampled_uniform | J=4] Round 70/2000 Time=18.1s | Local Acc=0.328±0.042 | Val Acc=0.110 | Test Acc=0.123
# [sampled_uniform | J=4] Round 71/2000 Time=18.0s | Local Acc=0.437±0.116 | Val Acc=0.095 | Test Acc=0.104
# [sampled_uniform | J=4] Round 72/2000 Time=19.1s | Local Acc=0.385±0.075 | Val Acc=0.096 | Test Acc=0.110
# [sampled_uniform | J=4] Round 73/2000 Time=17.8s | Local Acc=0.409±0.104 | Val Acc=0.096 | Test Acc=0.114
# [sampled_uniform | J=4] Round 74/2000 Time=18.5s | Local Acc=0.436±0.169 | Val Acc=0.081 | Test Acc=0.100
# [sampled_uniform | J=4] Round 75/2000 Time=18.5s | Local Acc=0.410±0.145 | Val Acc=0.100 | Test Acc=0.111
# [sampled_uniform | J=4] Round 76/2000 Time=17.9s | Local Acc=0.416±0.114 | Val Acc=0.104 | Test Acc=0.121
# [sampled_uniform | J=4] Round 77/2000 Time=20.6s | Local Acc=0.415±0.137 | Val Acc=0.098 | Test Acc=0.101
# [sampled_uniform | J=4] Round 78/2000 Time=18.3s | Local Acc=0.419±0.157 | Val Acc=0.099 | Test Acc=0.113
# [sampled_uniform | J=4] Round 79/2000 Time=18.5s | Local Acc=0.436±0.133 | Val Acc=0.110 | Test Acc=0.133
# [sampled_uniform | J=4] Round 80/2000 Time=19.1s | Local Acc=0.530±0.136 | Val Acc=0.100 | Test Acc=0.110
# [sampled_uniform | J=4] Checkpointing at round 80/2000
#     → Last Val Acc: 0.1004 | Last Val Loss: 3.8447
#     → Last Test Acc: 0.1104 | Last Test Loss: 3.7836
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_80.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 81/2000 Time=18.0s | Local Acc=0.383±0.091 | Val Acc=0.122 | Test Acc=0.122
# [sampled_uniform | J=4] Round 82/2000 Time=19.3s | Local Acc=0.475±0.150 | Val Acc=0.102 | Test Acc=0.110
# [sampled_uniform | J=4] Round 83/2000 Time=18.2s | Local Acc=0.472±0.149 | Val Acc=0.093 | Test Acc=0.110
# [sampled_uniform | J=4] Round 84/2000 Time=18.0s | Local Acc=0.400±0.126 | Val Acc=0.114 | Test Acc=0.133
# [sampled_uniform | J=4] Round 85/2000 Time=19.4s | Local Acc=0.504±0.177 | Val Acc=0.079 | Test Acc=0.098
# [sampled_uniform | J=4] Round 86/2000 Time=17.9s | Local Acc=0.437±0.127 | Val Acc=0.108 | Test Acc=0.122
# [sampled_uniform | J=4] Round 87/2000 Time=18.2s | Local Acc=0.465±0.178 | Val Acc=0.105 | Test Acc=0.115
# [sampled_uniform | J=4] Round 88/2000 Time=18.8s | Local Acc=0.393±0.105 | Val Acc=0.101 | Test Acc=0.118
# [sampled_uniform | J=4] Round 89/2000 Time=19.4s | Local Acc=0.390±0.139 | Val Acc=0.102 | Test Acc=0.107
# [sampled_uniform | J=4] Round 90/2000 Time=19.5s | Local Acc=0.447±0.144 | Val Acc=0.098 | Test Acc=0.112
# [sampled_uniform | J=4] Round 91/2000 Time=17.9s | Local Acc=0.433±0.155 | Val Acc=0.099 | Test Acc=0.103
# [sampled_uniform | J=4] Round 92/2000 Time=18.1s | Local Acc=0.433±0.092 | Val Acc=0.108 | Test Acc=0.130
# [sampled_uniform | J=4] Round 93/2000 Time=19.1s | Local Acc=0.421±0.094 | Val Acc=0.126 | Test Acc=0.130
# [sampled_uniform | J=4] Round 94/2000 Time=18.1s | Local Acc=0.516±0.145 | Val Acc=0.120 | Test Acc=0.145
# [sampled_uniform | J=4] Round 95/2000 Time=19.5s | Local Acc=0.539±0.147 | Val Acc=0.118 | Test Acc=0.132
# [sampled_uniform | J=4] Round 96/2000 Time=17.9s | Local Acc=0.472±0.117 | Val Acc=0.113 | Test Acc=0.137
# [sampled_uniform | J=4] Round 97/2000 Time=18.0s | Local Acc=0.515±0.193 | Val Acc=0.133 | Test Acc=0.153
# [sampled_uniform | J=4] Round 98/2000 Time=19.3s | Local Acc=0.449±0.112 | Val Acc=0.116 | Test Acc=0.137
# [sampled_uniform | J=4] Round 99/2000 Time=17.8s | Local Acc=0.568±0.155 | Val Acc=0.107 | Test Acc=0.115
# [sampled_uniform | J=4] Round 100/2000 Time=18.7s | Local Acc=0.446±0.111 | Val Acc=0.107 | Test Acc=0.124
# [sampled_uniform | J=4] Checkpointing at round 100/2000
#     → Last Val Acc: 0.1072 | Last Val Loss: 3.9583
#     → Last Test Acc: 0.1243 | Last Test Loss: 3.7526
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_100.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 101/2000 Time=20.0s | Local Acc=0.424±0.115 | Val Acc=0.094 | Test Acc=0.105
# [sampled_uniform | J=4] Round 102/2000 Time=17.9s | Local Acc=0.520±0.165 | Val Acc=0.109 | Test Acc=0.127
# [sampled_uniform | J=4] Round 103/2000 Time=19.2s | Local Acc=0.419±0.107 | Val Acc=0.076 | Test Acc=0.093
# [sampled_uniform | J=4] Round 104/2000 Time=17.9s | Local Acc=0.545±0.164 | Val Acc=0.116 | Test Acc=0.135
# [sampled_uniform | J=4] Round 105/2000 Time=17.7s | Local Acc=0.423±0.082 | Val Acc=0.129 | Test Acc=0.139
# [sampled_uniform | J=4] Round 106/2000 Time=19.0s | Local Acc=0.434±0.104 | Val Acc=0.126 | Test Acc=0.136
# [sampled_uniform | J=4] Round 107/2000 Time=18.0s | Local Acc=0.459±0.144 | Val Acc=0.136 | Test Acc=0.151
# [sampled_uniform | J=4] Round 108/2000 Time=18.0s | Local Acc=0.534±0.149 | Val Acc=0.124 | Test Acc=0.135
# [sampled_uniform | J=4] Round 109/2000 Time=18.8s | Local Acc=0.480±0.097 | Val Acc=0.136 | Test Acc=0.143
# [sampled_uniform | J=4] Round 110/2000 Time=17.8s | Local Acc=0.567±0.154 | Val Acc=0.096 | Test Acc=0.115
# [sampled_uniform | J=4] Round 111/2000 Time=18.4s | Local Acc=0.471±0.101 | Val Acc=0.126 | Test Acc=0.130
# [sampled_uniform | J=4] Round 112/2000 Time=18.4s | Local Acc=0.604±0.167 | Val Acc=0.107 | Test Acc=0.124
# [sampled_uniform | J=4] Round 113/2000 Time=18.0s | Local Acc=0.466±0.129 | Val Acc=0.121 | Test Acc=0.137
# [sampled_uniform | J=4] Round 114/2000 Time=19.6s | Local Acc=0.505±0.167 | Val Acc=0.122 | Test Acc=0.147
# [sampled_uniform | J=4] Round 115/2000 Time=17.7s | Local Acc=0.488±0.129 | Val Acc=0.110 | Test Acc=0.133
# [sampled_uniform | J=4] Round 116/2000 Time=17.6s | Local Acc=0.470±0.130 | Val Acc=0.133 | Test Acc=0.154
# [sampled_uniform | J=4] Round 117/2000 Time=18.8s | Local Acc=0.471±0.094 | Val Acc=0.146 | Test Acc=0.170
# [sampled_uniform | J=4] Round 118/2000 Time=17.4s | Local Acc=0.514±0.097 | Val Acc=0.142 | Test Acc=0.155
# [sampled_uniform | J=4] Round 119/2000 Time=17.3s | Local Acc=0.452±0.100 | Val Acc=0.164 | Test Acc=0.177
# [sampled_uniform | J=4] Round 120/2000 Time=18.7s | Local Acc=0.481±0.153 | Val Acc=0.130 | Test Acc=0.132
# [sampled_uniform | J=4] Checkpointing at round 120/2000
#     → Last Val Acc: 0.1302 | Last Val Loss: 3.7388
#     → Last Test Acc: 0.1322 | Last Test Loss: 3.6998
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_120.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 121/2000 Time=17.4s | Local Acc=0.440±0.078 | Val Acc=0.141 | Test Acc=0.164
# [sampled_uniform | J=4] Round 122/2000 Time=17.6s | Local Acc=0.508±0.101 | Val Acc=0.128 | Test Acc=0.140
# [sampled_uniform | J=4] Round 123/2000 Time=20.1s | Local Acc=0.586±0.156 | Val Acc=0.130 | Test Acc=0.155
# [sampled_uniform | J=4] Round 124/2000 Time=17.4s | Local Acc=0.497±0.126 | Val Acc=0.123 | Test Acc=0.149
# [sampled_uniform | J=4] Round 125/2000 Time=17.7s | Local Acc=0.484±0.102 | Val Acc=0.168 | Test Acc=0.186
# [sampled_uniform | J=4] Round 126/2000 Time=18.7s | Local Acc=0.585±0.133 | Val Acc=0.151 | Test Acc=0.165
# [sampled_uniform | J=4] Round 127/2000 Time=17.4s | Local Acc=0.481±0.064 | Val Acc=0.162 | Test Acc=0.176
# [sampled_uniform | J=4] Round 128/2000 Time=18.3s | Local Acc=0.580±0.122 | Val Acc=0.153 | Test Acc=0.165
# [sampled_uniform | J=4] Round 129/2000 Time=18.4s | Local Acc=0.563±0.148 | Val Acc=0.185 | Test Acc=0.198
# [sampled_uniform | J=4] Round 130/2000 Time=17.7s | Local Acc=0.477±0.100 | Val Acc=0.171 | Test Acc=0.186
# [sampled_uniform | J=4] Round 131/2000 Time=18.3s | Local Acc=0.608±0.172 | Val Acc=0.173 | Test Acc=0.185
# [sampled_uniform | J=4] Round 132/2000 Time=18.1s | Local Acc=0.475±0.082 | Val Acc=0.163 | Test Acc=0.170
# [sampled_uniform | J=4] Round 133/2000 Time=17.7s | Local Acc=0.577±0.091 | Val Acc=0.175 | Test Acc=0.181
# [sampled_uniform | J=4] Round 134/2000 Time=19.0s | Local Acc=0.540±0.126 | Val Acc=0.159 | Test Acc=0.179
# [sampled_uniform | J=4] Round 135/2000 Time=19.1s | Local Acc=0.538±0.113 | Val Acc=0.160 | Test Acc=0.183
# [sampled_uniform | J=4] Round 136/2000 Time=17.6s | Local Acc=0.559±0.127 | Val Acc=0.161 | Test Acc=0.177
# [sampled_uniform | J=4] Round 137/2000 Time=19.2s | Local Acc=0.536±0.109 | Val Acc=0.147 | Test Acc=0.156
# [sampled_uniform | J=4] Round 138/2000 Time=17.6s | Local Acc=0.524±0.105 | Val Acc=0.167 | Test Acc=0.178
# [sampled_uniform | J=4] Round 139/2000 Time=17.6s | Local Acc=0.560±0.117 | Val Acc=0.167 | Test Acc=0.183
# [sampled_uniform | J=4] Round 140/2000 Time=19.1s | Local Acc=0.496±0.075 | Val Acc=0.176 | Test Acc=0.189
# [sampled_uniform | J=4] Checkpointing at round 140/2000
#     → Last Val Acc: 0.1758 | Last Val Loss: 3.4188
#     → Last Test Acc: 0.1894 | Last Test Loss: 3.3327
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_140.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 141/2000 Time=17.5s | Local Acc=0.550±0.133 | Val Acc=0.160 | Test Acc=0.177
# [sampled_uniform | J=4] Round 142/2000 Time=17.8s | Local Acc=0.564±0.129 | Val Acc=0.148 | Test Acc=0.164
# [sampled_uniform | J=4] Round 143/2000 Time=18.9s | Local Acc=0.557±0.114 | Val Acc=0.144 | Test Acc=0.163
# [sampled_uniform | J=4] Round 144/2000 Time=17.6s | Local Acc=0.529±0.126 | Val Acc=0.172 | Test Acc=0.199
# [sampled_uniform | J=4] Round 145/2000 Time=17.9s | Local Acc=0.594±0.144 | Val Acc=0.137 | Test Acc=0.162
# [sampled_uniform | J=4] Round 146/2000 Time=18.8s | Local Acc=0.538±0.117 | Val Acc=0.142 | Test Acc=0.164
# [sampled_uniform | J=4] Round 147/2000 Time=18.9s | Local Acc=0.576±0.154 | Val Acc=0.141 | Test Acc=0.162
# [sampled_uniform | J=4] Round 148/2000 Time=19.0s | Local Acc=0.633±0.146 | Val Acc=0.166 | Test Acc=0.182
# [sampled_uniform | J=4] Round 149/2000 Time=17.7s | Local Acc=0.560±0.107 | Val Acc=0.145 | Test Acc=0.176
# [sampled_uniform | J=4] Round 150/2000 Time=17.6s | Local Acc=0.548±0.123 | Val Acc=0.179 | Test Acc=0.182
# [sampled_uniform | J=4] Round 151/2000 Time=18.8s | Local Acc=0.507±0.091 | Val Acc=0.156 | Test Acc=0.180
# [sampled_uniform | J=4] Round 152/2000 Time=17.8s | Local Acc=0.538±0.088 | Val Acc=0.148 | Test Acc=0.167
# [sampled_uniform | J=4] Round 153/2000 Time=17.8s | Local Acc=0.503±0.094 | Val Acc=0.172 | Test Acc=0.197
# [sampled_uniform | J=4] Round 154/2000 Time=18.8s | Local Acc=0.524±0.072 | Val Acc=0.149 | Test Acc=0.171
# [sampled_uniform | J=4] Round 155/2000 Time=17.7s | Local Acc=0.601±0.106 | Val Acc=0.173 | Test Acc=0.193
# [sampled_uniform | J=4] Round 156/2000 Time=18.0s | Local Acc=0.624±0.168 | Val Acc=0.154 | Test Acc=0.184
# [sampled_uniform | J=4] Round 157/2000 Time=18.9s | Local Acc=0.562±0.083 | Val Acc=0.192 | Test Acc=0.210
# [sampled_uniform | J=4] Round 158/2000 Time=18.0s | Local Acc=0.536±0.103 | Val Acc=0.178 | Test Acc=0.197
# [sampled_uniform | J=4] Round 159/2000 Time=20.0s | Local Acc=0.585±0.173 | Val Acc=0.169 | Test Acc=0.199
# [sampled_uniform | J=4] Round 160/2000 Time=18.3s | Local Acc=0.591±0.155 | Val Acc=0.117 | Test Acc=0.130
# [sampled_uniform | J=4] Checkpointing at round 160/2000
#     → Last Val Acc: 0.1166 | Last Val Loss: 3.7570
#     → Last Test Acc: 0.1298 | Last Test Loss: 3.6281
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_160.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 161/2000 Time=17.6s | Local Acc=0.606±0.121 | Val Acc=0.171 | Test Acc=0.193
# [sampled_uniform | J=4] Round 162/2000 Time=19.0s | Local Acc=0.614±0.129 | Val Acc=0.176 | Test Acc=0.203
# [sampled_uniform | J=4] Round 163/2000 Time=18.0s | Local Acc=0.539±0.115 | Val Acc=0.161 | Test Acc=0.169
# [sampled_uniform | J=4] Round 164/2000 Time=17.8s | Local Acc=0.553±0.085 | Val Acc=0.143 | Test Acc=0.178
# [sampled_uniform | J=4] Round 165/2000 Time=19.0s | Local Acc=0.571±0.121 | Val Acc=0.164 | Test Acc=0.193
# [sampled_uniform | J=4] Round 166/2000 Time=17.9s | Local Acc=0.582±0.093 | Val Acc=0.202 | Test Acc=0.209
# [sampled_uniform | J=4] Round 167/2000 Time=17.9s | Local Acc=0.546±0.145 | Val Acc=0.191 | Test Acc=0.213
# [sampled_uniform | J=4] Round 168/2000 Time=18.9s | Local Acc=0.590±0.144 | Val Acc=0.180 | Test Acc=0.202
# [sampled_uniform | J=4] Round 169/2000 Time=17.4s | Local Acc=0.626±0.140 | Val Acc=0.152 | Test Acc=0.179
# [sampled_uniform | J=4] Round 170/2000 Time=17.5s | Local Acc=0.651±0.132 | Val Acc=0.176 | Test Acc=0.196
# [sampled_uniform | J=4] Round 171/2000 Time=20.0s | Local Acc=0.564±0.103 | Val Acc=0.178 | Test Acc=0.200
# [sampled_uniform | J=4] Round 172/2000 Time=17.4s | Local Acc=0.639±0.164 | Val Acc=0.178 | Test Acc=0.197
# [sampled_uniform | J=4] Round 173/2000 Time=17.3s | Local Acc=0.636±0.175 | Val Acc=0.178 | Test Acc=0.202
# [sampled_uniform | J=4] Round 174/2000 Time=18.7s | Local Acc=0.654±0.117 | Val Acc=0.173 | Test Acc=0.201
# [sampled_uniform | J=4] Round 175/2000 Time=17.5s | Local Acc=0.660±0.159 | Val Acc=0.162 | Test Acc=0.182
# [sampled_uniform | J=4] Round 176/2000 Time=17.3s | Local Acc=0.565±0.137 | Val Acc=0.215 | Test Acc=0.232
# [sampled_uniform | J=4] Round 177/2000 Time=18.7s | Local Acc=0.609±0.155 | Val Acc=0.186 | Test Acc=0.214
# [sampled_uniform | J=4] Round 178/2000 Time=17.4s | Local Acc=0.595±0.112 | Val Acc=0.180 | Test Acc=0.203
# [sampled_uniform | J=4] Round 179/2000 Time=17.5s | Local Acc=0.595±0.099 | Val Acc=0.186 | Test Acc=0.215
# [sampled_uniform | J=4] Round 180/2000 Time=18.8s | Local Acc=0.629±0.152 | Val Acc=0.178 | Test Acc=0.207
# [sampled_uniform | J=4] Checkpointing at round 180/2000
#     → Last Val Acc: 0.1782 | Last Val Loss: 3.3580
#     → Last Test Acc: 0.2074 | Last Test Loss: 3.1764
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_180.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 181/2000 Time=17.3s | Local Acc=0.534±0.081 | Val Acc=0.181 | Test Acc=0.204
# [sampled_uniform | J=4] Round 182/2000 Time=17.5s | Local Acc=0.622±0.126 | Val Acc=0.184 | Test Acc=0.207
# [sampled_uniform | J=4] Round 183/2000 Time=19.0s | Local Acc=0.513±0.053 | Val Acc=0.203 | Test Acc=0.228
# [sampled_uniform | J=4] Round 184/2000 Time=18.2s | Local Acc=0.622±0.121 | Val Acc=0.175 | Test Acc=0.198
# [sampled_uniform | J=4] Round 185/2000 Time=18.3s | Local Acc=0.617±0.163 | Val Acc=0.213 | Test Acc=0.232
# [sampled_uniform | J=4] Round 186/2000 Time=18.0s | Local Acc=0.592±0.113 | Val Acc=0.179 | Test Acc=0.203
# [sampled_uniform | J=4] Round 187/2000 Time=17.4s | Local Acc=0.585±0.118 | Val Acc=0.166 | Test Acc=0.213
# [sampled_uniform | J=4] Round 188/2000 Time=18.0s | Local Acc=0.564±0.133 | Val Acc=0.208 | Test Acc=0.211
# [sampled_uniform | J=4] Round 189/2000 Time=17.9s | Local Acc=0.586±0.065 | Val Acc=0.221 | Test Acc=0.243
# [sampled_uniform | J=4] Round 190/2000 Time=17.4s | Local Acc=0.646±0.180 | Val Acc=0.193 | Test Acc=0.230
# [sampled_uniform | J=4] Round 191/2000 Time=17.6s | Local Acc=0.590±0.147 | Val Acc=0.146 | Test Acc=0.164
# [sampled_uniform | J=4] Round 192/2000 Time=18.5s | Local Acc=0.592±0.143 | Val Acc=0.193 | Test Acc=0.220
# [sampled_uniform | J=4] Round 193/2000 Time=17.7s | Local Acc=0.640±0.113 | Val Acc=0.184 | Test Acc=0.206
# [sampled_uniform | J=4] Round 194/2000 Time=17.9s | Local Acc=0.699±0.130 | Val Acc=0.203 | Test Acc=0.213
# [sampled_uniform | J=4] Round 195/2000 Time=18.4s | Local Acc=0.612±0.130 | Val Acc=0.201 | Test Acc=0.219
# [sampled_uniform | J=4] Round 196/2000 Time=18.6s | Local Acc=0.638±0.130 | Val Acc=0.193 | Test Acc=0.222
# [sampled_uniform | J=4] Round 197/2000 Time=18.9s | Local Acc=0.673±0.141 | Val Acc=0.213 | Test Acc=0.222
# [sampled_uniform | J=4] Round 198/2000 Time=17.8s | Local Acc=0.566±0.084 | Val Acc=0.194 | Test Acc=0.217
# [sampled_uniform | J=4] Round 199/2000 Time=17.4s | Local Acc=0.608±0.104 | Val Acc=0.188 | Test Acc=0.221
# [sampled_uniform | J=4] Round 200/2000 Time=18.4s | Local Acc=0.547±0.098 | Val Acc=0.212 | Test Acc=0.239
# [sampled_uniform | J=4] Checkpointing at round 200/2000
#     → Last Val Acc: 0.2118 | Last Val Loss: 3.2377
#     → Last Test Acc: 0.2390 | Last Test Loss: 3.0741
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_200.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 201/2000 Time=17.4s | Local Acc=0.588±0.082 | Val Acc=0.234 | Test Acc=0.240
# [sampled_uniform | J=4] Round 202/2000 Time=17.4s | Local Acc=0.592±0.112 | Val Acc=0.203 | Test Acc=0.233
# [sampled_uniform | J=4] Round 203/2000 Time=18.5s | Local Acc=0.629±0.126 | Val Acc=0.209 | Test Acc=0.222
# [sampled_uniform | J=4] Round 204/2000 Time=17.6s | Local Acc=0.623±0.140 | Val Acc=0.214 | Test Acc=0.241
# [sampled_uniform | J=4] Round 205/2000 Time=17.4s | Local Acc=0.639±0.132 | Val Acc=0.236 | Test Acc=0.246
# [sampled_uniform | J=4] Round 206/2000 Time=18.1s | Local Acc=0.624±0.113 | Val Acc=0.224 | Test Acc=0.236
# [sampled_uniform | J=4] Round 207/2000 Time=17.9s | Local Acc=0.606±0.078 | Val Acc=0.239 | Test Acc=0.249
# [sampled_uniform | J=4] Round 208/2000 Time=18.5s | Local Acc=0.598±0.076 | Val Acc=0.239 | Test Acc=0.257
# [sampled_uniform | J=4] Round 209/2000 Time=19.0s | Local Acc=0.605±0.086 | Val Acc=0.194 | Test Acc=0.222
# [sampled_uniform | J=4] Round 210/2000 Time=17.9s | Local Acc=0.651±0.134 | Val Acc=0.214 | Test Acc=0.223
# [sampled_uniform | J=4] Round 211/2000 Time=17.4s | Local Acc=0.674±0.130 | Val Acc=0.236 | Test Acc=0.252
# [sampled_uniform | J=4] Round 212/2000 Time=18.8s | Local Acc=0.670±0.134 | Val Acc=0.185 | Test Acc=0.220
# [sampled_uniform | J=4] Round 213/2000 Time=17.4s | Local Acc=0.646±0.113 | Val Acc=0.201 | Test Acc=0.222
# [sampled_uniform | J=4] Round 214/2000 Time=17.3s | Local Acc=0.597±0.079 | Val Acc=0.243 | Test Acc=0.268
# [sampled_uniform | J=4] Round 215/2000 Time=19.0s | Local Acc=0.722±0.075 | Val Acc=0.229 | Test Acc=0.258
# [sampled_uniform | J=4] Round 216/2000 Time=17.4s | Local Acc=0.657±0.151 | Val Acc=0.206 | Test Acc=0.226
# [sampled_uniform | J=4] Round 217/2000 Time=17.3s | Local Acc=0.636±0.116 | Val Acc=0.219 | Test Acc=0.245
# [sampled_uniform | J=4] Round 218/2000 Time=18.3s | Local Acc=0.584±0.110 | Val Acc=0.188 | Test Acc=0.232
# [sampled_uniform | J=4] Round 219/2000 Time=17.2s | Local Acc=0.656±0.121 | Val Acc=0.205 | Test Acc=0.229
# [sampled_uniform | J=4] Round 220/2000 Time=18.7s | Local Acc=0.656±0.107 | Val Acc=0.203 | Test Acc=0.238
# [sampled_uniform | J=4] Checkpointing at round 220/2000
#     → Last Val Acc: 0.2032 | Last Val Loss: 3.3249
#     → Last Test Acc: 0.2384 | Last Test Loss: 3.1118
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_220.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 221/2000 Time=18.2s | Local Acc=0.640±0.130 | Val Acc=0.194 | Test Acc=0.231
# [sampled_uniform | J=4] Round 222/2000 Time=17.6s | Local Acc=0.665±0.109 | Val Acc=0.192 | Test Acc=0.214
# [sampled_uniform | J=4] Round 223/2000 Time=17.0s | Local Acc=0.644±0.104 | Val Acc=0.221 | Test Acc=0.241
# [sampled_uniform | J=4] Round 224/2000 Time=17.5s | Local Acc=0.644±0.087 | Val Acc=0.202 | Test Acc=0.218
# [sampled_uniform | J=4] Round 225/2000 Time=18.0s | Local Acc=0.608±0.080 | Val Acc=0.207 | Test Acc=0.232
# [sampled_uniform | J=4] Round 226/2000 Time=16.9s | Local Acc=0.689±0.108 | Val Acc=0.191 | Test Acc=0.220
# [sampled_uniform | J=4] Round 227/2000 Time=17.1s | Local Acc=0.671±0.119 | Val Acc=0.229 | Test Acc=0.259
# [sampled_uniform | J=4] Round 228/2000 Time=18.4s | Local Acc=0.678±0.110 | Val Acc=0.218 | Test Acc=0.249
# [sampled_uniform | J=4] Round 229/2000 Time=17.1s | Local Acc=0.648±0.123 | Val Acc=0.243 | Test Acc=0.267
# [sampled_uniform | J=4] Round 230/2000 Time=17.1s | Local Acc=0.651±0.066 | Val Acc=0.233 | Test Acc=0.259
# [sampled_uniform | J=4] Round 231/2000 Time=18.5s | Local Acc=0.653±0.117 | Val Acc=0.218 | Test Acc=0.243
# [sampled_uniform | J=4] Round 232/2000 Time=18.7s | Local Acc=0.645±0.121 | Val Acc=0.256 | Test Acc=0.264
# [sampled_uniform | J=4] Round 233/2000 Time=17.1s | Local Acc=0.643±0.059 | Val Acc=0.247 | Test Acc=0.273
# [sampled_uniform | J=4] Round 234/2000 Time=18.3s | Local Acc=0.676±0.145 | Val Acc=0.209 | Test Acc=0.230
# [sampled_uniform | J=4] Round 235/2000 Time=17.0s | Local Acc=0.659±0.108 | Val Acc=0.244 | Test Acc=0.265
# [sampled_uniform | J=4] Round 236/2000 Time=17.1s | Local Acc=0.636±0.095 | Val Acc=0.238 | Test Acc=0.255
# [sampled_uniform | J=4] Round 237/2000 Time=18.3s | Local Acc=0.652±0.091 | Val Acc=0.226 | Test Acc=0.258
# [sampled_uniform | J=4] Round 238/2000 Time=17.3s | Local Acc=0.639±0.071 | Val Acc=0.241 | Test Acc=0.264
# [sampled_uniform | J=4] Round 239/2000 Time=17.0s | Local Acc=0.676±0.116 | Val Acc=0.217 | Test Acc=0.224
# [sampled_uniform | J=4] Round 240/2000 Time=17.2s | Local Acc=0.654±0.090 | Val Acc=0.234 | Test Acc=0.248
# [sampled_uniform | J=4] Checkpointing at round 240/2000
#     → Last Val Acc: 0.2336 | Last Val Loss: 3.1621
#     → Last Test Acc: 0.2483 | Last Test Loss: 3.0452
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_240.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 241/2000 Time=17.7s | Local Acc=0.634±0.060 | Val Acc=0.231 | Test Acc=0.248
# [sampled_uniform | J=4] Round 242/2000 Time=16.9s | Local Acc=0.660±0.106 | Val Acc=0.234 | Test Acc=0.252
# [sampled_uniform | J=4] Round 243/2000 Time=17.0s | Local Acc=0.654±0.088 | Val Acc=0.222 | Test Acc=0.255
# [sampled_uniform | J=4] Round 244/2000 Time=18.2s | Local Acc=0.672±0.118 | Val Acc=0.237 | Test Acc=0.260
# [sampled_uniform | J=4] Round 245/2000 Time=18.0s | Local Acc=0.661±0.082 | Val Acc=0.264 | Test Acc=0.281
# [sampled_uniform | J=4] Round 246/2000 Time=16.9s | Local Acc=0.688±0.111 | Val Acc=0.243 | Test Acc=0.269
# [sampled_uniform | J=4] Round 247/2000 Time=18.2s | Local Acc=0.670±0.111 | Val Acc=0.237 | Test Acc=0.265
# [sampled_uniform | J=4] Round 248/2000 Time=17.0s | Local Acc=0.631±0.121 | Val Acc=0.211 | Test Acc=0.252
# [sampled_uniform | J=4] Round 249/2000 Time=17.0s | Local Acc=0.625±0.084 | Val Acc=0.246 | Test Acc=0.280
# [sampled_uniform | J=4] Round 250/2000 Time=18.3s | Local Acc=0.696±0.068 | Val Acc=0.193 | Test Acc=0.231
# [sampled_uniform | J=4] Round 251/2000 Time=17.1s | Local Acc=0.652±0.101 | Val Acc=0.239 | Test Acc=0.258
# [sampled_uniform | J=4] Round 252/2000 Time=16.9s | Local Acc=0.654±0.119 | Val Acc=0.251 | Test Acc=0.279
# [sampled_uniform | J=4] Round 253/2000 Time=17.5s | Local Acc=0.703±0.080 | Val Acc=0.259 | Test Acc=0.278
# [sampled_uniform | J=4] Round 254/2000 Time=17.6s | Local Acc=0.686±0.131 | Val Acc=0.250 | Test Acc=0.287
# [sampled_uniform | J=4] Round 255/2000 Time=16.9s | Local Acc=0.700±0.085 | Val Acc=0.221 | Test Acc=0.247
# [sampled_uniform | J=4] Round 256/2000 Time=16.9s | Local Acc=0.685±0.121 | Val Acc=0.200 | Test Acc=0.222
# [sampled_uniform | J=4] Round 257/2000 Time=19.6s | Local Acc=0.676±0.106 | Val Acc=0.226 | Test Acc=0.247
# [sampled_uniform | J=4] Round 258/2000 Time=16.9s | Local Acc=0.658±0.104 | Val Acc=0.156 | Test Acc=0.178
# [sampled_uniform | J=4] Round 259/2000 Time=16.9s | Local Acc=0.670±0.113 | Val Acc=0.228 | Test Acc=0.256
# [sampled_uniform | J=4] Round 260/2000 Time=18.1s | Local Acc=0.647±0.085 | Val Acc=0.252 | Test Acc=0.277
# [sampled_uniform | J=4] Checkpointing at round 260/2000
#     → Last Val Acc: 0.2516 | Last Val Loss: 3.0133
#     → Last Test Acc: 0.2771 | Last Test Loss: 2.8603
# [Checkpoint] Saved sampled_uniform_J4_last_ckpt_round_260.pth
# [sampled_uniform | J=4] Checkpoint saved.
#
# [sampled_uniform | J=4] Round 261/2000 Time=17.0s | Local Acc=0.688±0.116 | Val Acc=0.231 | Test Acc=0.256
# [sampled_uniform | J=4] Round 262/2000 Time=16.9s | Local Acc=0.710±0.129 | Val Acc=0.225 | Test Acc=0.255
# [sampled_uniform | J=4] Round 263/2000 Time=17.7s | Local Acc=0.722±0.118 | Val Acc=0.251 | Test Acc=0.263

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ── A. Mount Google Drive ─────────────────────────────────────────────────────
from google.colab import drive
import os

drive.mount('/content/drive')

# Path al CSV (modifica se hai più file, oppure fai un loop sugli altri)
CSV_PATH = "/content/drive/MyDrive/Nc_entropy_JS/Nc_entropy_JS_fedavg_results.csv"

df = pd.read_csv(CSV_PATH)

# Controlliamo le colonne disponibili
print("Colonne CSV:", df.columns.tolist())
print("Metodi disponibili:", df["name"].unique())

# Organizziamo i risultati in un dizionario
results = {}
for name, group in df.groupby("name"):
    group_sorted = group.sort_values("round")
    results[name] = {
        "round": group_sorted["round"].tolist(),
        "val_acc": group_sorted["val_acc"].tolist(),
        "test_acc": group_sorted["test_acc"].tolist(),
        "val_loss": group_sorted["val_loss"].tolist(),
        "test_loss": group_sorted["test_loss"].tolist(),
    }

# --------- GRAFICI ---------

# 1. Validation Accuracy vs Round
plt.figure(figsize=(8,6))
for method, metrics in results.items():
    plt.plot(metrics["round"], metrics["val_acc"], label=method)
plt.xlabel("Round")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Round")
plt.legend()
plt.grid(True)
plt.show()

# 2. Test Accuracy vs Validation Accuracy
plt.figure(figsize=(8,6))
for method, metrics in results.items():
    plt.plot(metrics["val_acc"], metrics["test_acc"], "o-", label=method)
plt.xlabel("Validation Accuracy")
plt.ylabel("Test Accuracy")
plt.title("Test vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# 3. Loss vs Round
plt.figure(figsize=(8,6))
for method, metrics in results.items():
    plt.plot(metrics["round"], metrics["val_loss"], label=f"{method} val_loss")
    plt.plot(metrics["round"], metrics["test_loss"], linestyle="--", label=f"{method} test_loss")
plt.xlabel("Round")
plt.ylabel("Loss")
plt.title("Loss vs Round")
plt.legend()
plt.grid(True)
plt.show()

# 4. Zoom ultimi 20 round (Validation Accuracy)
plt.figure(figsize=(8,6))
last_k = 20
for method, metrics in results.items():
    plt.plot(metrics["round"][-last_k:], metrics["val_acc"][-last_k:], label=method)
plt.xlabel("Round")
plt.ylabel("Validation Accuracy")
plt.title(f"Validation Accuracy (ultimi {last_k} round)")
plt.legend()
plt.grid(True)
plt.show()

# 5. Boxplot delle accuracies finali
final_val_accs = [metrics["val_acc"][-1] for metrics in results.values() if metrics["val_acc"]]
plt.figure(figsize=(6,6))
plt.boxplot(final_val_accs, labels=list(results.keys()))
plt.ylabel("Final Validation Accuracy")
plt.title("Distribuzione delle accuracies finali")
plt.grid(True)
plt.show()

# %%
# ==== Analysis & Plots: smoothing + uncertainty bands ====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- Config ---
CSV_PATH = "/content/drive/MyDrive/Nc_entropy_JS/Nc_entropy_JS_fedavg_results.csv"  # cambia se serve
COL_ROUND = "round"
COL_NAME  = "name"
COL_VAL_A = "val_acc"
COL_TEST_A= "test_acc"
COL_VAL_L = "val_loss"
COL_TEST_L= "test_loss"

WIN_MA    = 5     # finestra media mobile (round)
ALPHA_EMA = 0.3   # smoothing EMA (0<alpha<=1)
ROLL_BAND = 7     # finestra per bande (rolling std)
LAST_N    = 10    # media sugli ultimi N round per confronto robusto

# --- Utils ---
def moving_average(x, w):
    x = np.asarray(x, dtype=float)
    if len(x) < w:
        return np.array([])
    return np.convolve(x, np.ones(w)/w, mode='valid')

def ema(x, alpha):
    x = np.asarray(x, dtype=float)
    if len(x) == 0:
        return np.array([])
    out = np.zeros_like(x, dtype=float)
    out[0] = x[0]
    for i in range(1, len(x)):
        out[i] = alpha*x[i] + (1-alpha)*out[i-1]
    return out

def rolling_std(x, w):
    x = pd.Series(x, dtype=float)
    return x.rolling(window=w, min_periods=max(2, w//2)).std().to_numpy()

# --- Load ---
df = pd.read_csv(CSV_PATH)
assert {COL_ROUND, COL_NAME, COL_VAL_A, COL_TEST_A}.issubset(df.columns), f"Mancano colonne richieste in {CSV_PATH}"
df = df.sort_values(COL_ROUND)

methods = df[COL_NAME].unique()
print("Metodi:", methods)

# --- Build per-method series ---
series = {}
for m in methods:
    g = df[df[COL_NAME]==m].sort_values(COL_ROUND)
    rounds  = g[COL_ROUND].to_numpy()
    val_acc = g[COL_VAL_A].to_numpy()
    test_acc= g[COL_TEST_A].to_numpy() if COL_TEST_A in g else np.array([])
    val_loss= g[COL_VAL_L].to_numpy() if COL_VAL_L in g else np.array([])
    test_loss= g[COL_TEST_L].to_numpy() if COL_TEST_L in g else np.array([])

    series[m] = dict(
        rounds=rounds,
        val_acc=val_acc, test_acc=test_acc,
        val_loss=val_loss, test_loss=test_loss
    )

# --- 1) Validation Accuracy: raw + smoothed + bands ---
plt.figure(figsize=(9,6))
for m, s in series.items():
    r   = s["rounds"]
    va  = s["val_acc"]
    if len(va)==0:
        continue

    # raw (trasparente)
    plt.plot(r, va, alpha=0.35, label=f"{m} (raw)")

    # MA (accorcia l’asse x di WIN_MA-1)
    ma  = moving_average(va, WIN_MA)
    if len(ma)>0:
        plt.plot(r[WIN_MA-1:], ma, linewidth=2, label=f"{m} (MA{WIN_MA})")

    # EMA (stessa lunghezza)
    ea  = ema(va, ALPHA_EMA)
    plt.plot(r, ea, linestyle="--", linewidth=1.5, label=f"{m} (EMA {ALPHA_EMA})")

    # Bande (± rolling std) intorno alla EMA
    rs  = rolling_std(va, ROLL_BAND)
    if len(rs)>0:
        upper = ea + rs
        lower = ea - rs
        plt.fill_between(r, lower, upper, alpha=0.12)

plt.xlabel("Round")
plt.ylabel("Validation Accuracy")
plt.title(f"Validation Accuracy vs Round — raw, MA({WIN_MA}), EMA(α={ALPHA_EMA}) + rolling std({ROLL_BAND})")
plt.grid(True)
plt.legend(ncol=2, fontsize=9)
plt.show()

# --- 2) Test vs Validation (curva + EMA) ---
plt.figure(figsize=(8,6))
for m, s in series.items():
    va, ta = s["val_acc"], s["test_acc"]
    if len(va)==0 or len(ta)==0:
        continue
    plt.plot(va, ta, "o", alpha=0.25, label=f"{m} points")
    # Linea ordinando per val_acc e tracciando EMA in funzione di val_acc
    order = np.argsort(va)
    va_ord = va[order]
    ta_ord = ta[order]
    ta_ema = ema(ta_ord, ALPHA_EMA)
    plt.plot(va_ord, ta_ema, linewidth=2, label=f"{m} EMA")
plt.xlabel("Validation Accuracy")
plt.ylabel("Test Accuracy")
plt.title("Test vs Validation Accuracy (con smoothing)")
plt.grid(True)
plt.legend()
plt.show()

# --- 3) Loss (val/test) raw + MA ---
plt.figure(figsize=(9,6))
for m, s in series.items():
    r, vl, tl = s["rounds"], s["val_loss"], s["test_loss"]
    if len(vl)>0:
        plt.plot(r, vl, alpha=0.4, label=f"{m} val_loss")
        vl_ma = moving_average(vl, WIN_MA)
        if len(vl_ma)>0:
            plt.plot(r[WIN_MA-1:], vl_ma, linewidth=2, label=f"{m} val_loss MA{WIN_MA}")
    if len(tl)>0:
        plt.plot(r, tl, alpha=0.4, linestyle="--", label=f"{m} test_loss")
        tl_ma = moving_average(tl, WIN_MA)
        if len(tl_ma)>0:
            plt.plot(r[WIN_MA-1:], tl_ma, linewidth=2, linestyle="--", label=f"{m} test_loss MA{WIN_MA}")
plt.xlabel("Round")
plt.ylabel("Loss")
plt.title("Loss vs Round (raw + moving average)")
plt.grid(True)
plt.legend(ncol=2, fontsize=9)
plt.show()

# --- 4) Zoom ultimi N round (val_acc, con MA/EMA) ---
plt.figure(figsize=(9,6))
for m, s in series.items():
    r, va = s["rounds"], s["val_acc"]
    if len(va)==0: continue
    rZ, vaZ = r[-LAST_N:], va[-LAST_N:]
    plt.plot(rZ, vaZ, alpha=0.35, label=f"{m} raw")
    eaZ = ema(vaZ, ALPHA_EMA)
    plt.plot(rZ, eaZ, linestyle="--", linewidth=2, label=f"{m} EMA")
plt.xlabel("Round (ultimi)")
plt.ylabel("Validation Accuracy")
plt.title(f"Validation Accuracy — Zoom ultimi {LAST_N} round")
plt.grid(True)
plt.legend(ncol=2, fontsize=9)
plt.show()

# --- 5) Tabella confronto robusto sugli ultimi N round ---
rows = []
for m, s in series.items():
    va, ta = s["val_acc"], s["test_acc"]
    if len(va)>=LAST_N:
        v_last = va[-LAST_N:]
        row = {
            "method": m,
            f"val_acc_mean_last{LAST_N}": float(np.mean(v_last)),
            f"val_acc_std_last{LAST_N}":  float(np.std(v_last))
        }
        if len(ta)>=LAST_N:
            t_last = ta[-LAST_N:]
            row.update({
                f"test_acc_mean_last{LAST_N}": float(np.mean(t_last)),
                f"test_acc_std_last{LAST_N}":  float(np.std(t_last))
            })
        rows.append(row)

summary_df = pd.DataFrame(rows).sort_values(f"val_acc_mean_last{LAST_N}", ascending=False)
print("\n== Confronto robusto (media±std ultimi N round) ==")
print(summary_df.to_string(index=False))

# %%
#ATTENZIONE!!!!
#OCCHIO A RUNNAREEEE



#utility function that deletes all checkpoints from the checkpoint folder

def clear_checkpoints(ckpt_dir):
    """
    Remove all checkpoint files in the specified dire ctory.
    """
    removed = 0
    for fname in os.listdir(ckpt_dir):
        path = os.path.join(ckpt_dir, fname)
        if os.path.isfile(path):
            os.remove(path)
            removed += 1
    print(f"[Checkpoint] Cleared {removed} files from {ckpt_dir}")


##clear_checkpoints(CKPT_DIR)
