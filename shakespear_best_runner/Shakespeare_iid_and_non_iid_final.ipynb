# %%
# ---------------- Full runnable Colab cell (copy-paste) ----------------
import random, math, time
import numpy as np
import torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import DataLoader, Subset, Dataset
import matplotlib.pyplot as plt
from datasets import load_dataset
from collections import defaultdict

# ---------------- settings (tune these) ----------------
K = 100                    # number of clients
C = 0.1                    # fraction of clients per round
CLIENTS_PER_ROUND = max(1, int(math.ceil(C * K)))
ROUNDS = 200                # number of federated rounds per experiment
LOCAL_STEPS_LIST = [1, 4, 8, 16]
BASE_J = 4
CLIENT_BATCH = 16
EMB_DIM = 32
HIDDEN_DIM = 128
LR_LOCAL = 1e-3
SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
GAMMAS = [0.01, 0.1, 1.0, 10.0]  # dirichlet concentration values for skewed scheme
log_every = 1      # print participation summary every `log_every` rounds
topk = 5

# ----------------------------------------------------------------------

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# ---------------- load dataset & build vocab ----------------
print("Loading Shakespeare dataset (this may take a few seconds)...")
hf = load_dataset("flwrlabs/shakespeare", split="train").shuffle(seed=SEED)

# train/val split
parts = hf.train_test_split(test_size=0.1, seed=SEED)
train_hf = parts['train']
val_hf = parts['test']

# build vocab from training split
chars = sorted({c for txt in train_hf['x'] for c in txt} | set(train_hf['y']))
PAD_TOKEN = "<pad>"
vocab = [PAD_TOKEN] + chars
char2idx = {c:i for i,c in enumerate(vocab)}
idx2char = {i:c for c,i in char2idx.items()}
VOCAB_SIZE = len(vocab)
print(f"Train size: {len(train_hf)}, Val size: {len(val_hf)}, Vocab size: {VOCAB_SIZE}")

# ---------------- dataset wrapper that returns tensors (consistent shape) ----------------
class ShakespeareDataset(Dataset):
    def __init__(self, hf_dataset, char2idx):
        self.hf = hf_dataset
        self.char2idx = char2idx
    def __len__(self):
        return len(self.hf)
    def __getitem__(self, idx):
        item = self.hf[int(idx)]
        x_str = item['x']
        y_str = item['y']
        x_idx = torch.tensor([self.char2idx[ch] for ch in x_str], dtype=torch.long)
        y_idx = torch.tensor(self.char2idx[y_str], dtype=torch.long)
        return x_idx, y_idx

train_ds = ShakespeareDataset(train_hf, char2idx)
val_ds = ShakespeareDataset(val_hf, char2idx)

# ---------------- IID shard function (index-based) ----------------
def iid_shards_by_chunk_indices(dataset_len, num_clients=100, seed=42):
    idxs = list(range(dataset_len))
    random.Random(seed).shuffle(idxs)
    shards = [[] for _ in range(num_clients)]
    for i, idx in enumerate(idxs):
        shards[i % num_clients].append(idx)
    return shards

client_indices_iid = iid_shards_by_chunk_indices(len(train_ds), num_clients=K, seed=SEED)
print("Example shard sizes (first 10):", [len(client_indices_iid[i]) for i in range(10)])

# ---------------- model definition ----------------
class CharLSTM(nn.Module):
    def __init__(self, vocab_size, emb=EMB_DIM, hid=HIDDEN_DIM, pad_idx=0):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, emb, padding_idx=pad_idx)
        self.lstm = nn.LSTM(emb, hid, batch_first=True)
        self.fc = nn.Linear(hid, vocab_size)
    def forward(self, x):
        e = self.embed(x)
        out, _ = self.lstm(e)
        return self.fc(out[:, -1, :])

# ---------------- evaluate helper ----------------
def evaluate(model, dataset, device=DEVICE, batch_size=256):
    model.eval()
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    loss_fn = nn.CrossEntropyLoss()
    total_loss = 0.0; total = 0; correct = 0
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = loss_fn(logits, yb)
            total_loss += loss.item() * xb.size(0)
            preds = logits.argmax(dim=1)
            correct += (preds == yb).sum().item()
            total += xb.size(0)
    return total_loss / total, correct / total

# ---------------- client local update (expects dataset returning (x_tensor,y_tensor)) ----------------
def client_update(global_state, client_idx_list, train_dataset, steps, batch_size=CLIENT_BATCH, lr=LR_LOCAL, device=DEVICE):
    """
    Local client training starting from global_state.
    Returns (state_cpu_dict, num_examples).
    Assumes train_dataset[i] returns (x_tensor, y_tensor).
    """
    if len(client_idx_list) == 0:
        return None, 0

    # DataLoader for this client's subset
    subset = Subset(train_dataset, client_idx_list)
    loader = DataLoader(subset, batch_size=batch_size, shuffle=True)

    # local model init
    local_model = CharLSTM(VOCAB_SIZE).to(device)
    local_model.load_state_dict(global_state)
    opt = optim.Adam(local_model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()

    it = iter(loader)
    steps_done = 0
    while steps_done < steps:
        try:
            xb, yb = next(it)
        except StopIteration:
            it = iter(loader)
            xb, yb = next(it)
        xb, yb = xb.to(device), yb.to(device)
        opt.zero_grad()
        logits = local_model(xb)
        loss = loss_fn(logits, yb)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(local_model.parameters(), max_norm=1.0)
        opt.step()
        steps_done += 1

    state_cpu = {k: v.cpu().clone() for k, v in local_model.state_dict().items()}
    return state_cpu, len(client_idx_list)

# ---------------- aggregation helper ----------------
def aggregate_states(local_states, local_sizes):
    """Weighted average of CPU state dicts."""
    new_state = {}
    total = float(sum(local_sizes))
    keys = local_states[0].keys()
    for k in keys:
        new_state[k] = torch.zeros_like(local_states[0][k], dtype=local_states[0][k].dtype)
        for s, sz in zip(local_states, local_sizes):
            new_state[k] += s[k] * (sz / total)
    return new_state

# ---------------- sampling function (Dirichlet skew) ----------------
def sample_skewed_clients(K, C, gamma):
    """
    Draw Dirichlet probabilities and sample clients without replacement.
    Defensively handles numerical issues by falling back to uniform p if needed.
    Returns (selected_list, pvec)
    """
    if gamma is None or not (isinstance(gamma, (int, float)) and gamma > 0):
        raise ValueError("gamma must be a positive float for skewed sampling")

    p = np.random.dirichlet([gamma] * K)
    # defensive normalization / fallback
    if np.isnan(p).any() or p.sum() == 0:
        p = np.ones(K) / K
    else:
        p = p / p.sum()

    num_sel = max(1, int(math.ceil(C * K)))
    selected = list(np.random.choice(np.arange(K), size=num_sel, replace=False, p=p))
    return selected, p

# ---------------- optional: non-iid shard creator (by target label count Nc) ----------------
def create_label_shards(train_dataset, idx2char, K, Nc, seed=SEED):
    """
    Create client shards where each client has at most Nc distinct target labels.
    Returns client_indices list-of-lists and clients_allowed (labels per client).
    """
    random.seed(seed)
    all_labels = list(idx2char.values())  # char list
    clients_allowed = []
    for k in range(K):
        allowed = random.sample(all_labels, min(Nc, len(all_labels)))
        clients_allowed.append(set(allowed))

    # Ensure each label appears at least once
    label_to_clients = defaultdict(list)
    for k, labels in enumerate(clients_allowed):
        for lab in labels:
            label_to_clients[lab].append(k)
    for lab in all_labels:
        if len(label_to_clients[lab]) == 0:
            k = random.randrange(K)
            clients_allowed[k].add(lab)
            label_to_clients[lab].append(k)

    # assign examples to clients that have that label in their allowed set
    client_indices = [[] for _ in range(K)]
    for i in range(len(train_dataset)):
        _, y = train_dataset[i]
        label_char = idx2char[int(y.item())]
        eligible = label_to_clients[label_char]
        chosen = random.choice(eligible)
        client_indices[chosen].append(i)
    return client_indices, clients_allowed

# ---------------- main experiment loop: uniform vs skewed ----------------
results = {}
device = DEVICE

schemes = ['uniform', 'skewed']

for scheme in schemes:
    # choose which gamma values to iterate for this scheme
    if scheme == 'uniform':
        gamma_iter = [None]
    else:
        gamma_iter = GAMMAS

    for gamma in gamma_iter:
        scheme_name_base = f"{scheme}" if gamma is None else f"{scheme}_gamma{gamma}"
        for J in LOCAL_STEPS_LIST:
            # compute rounds to keep total local updates ~constant
            rounds = max(1, math.ceil((ROUNDS * BASE_J) / float(J)))
            scheme_name = f"{scheme_name_base}_J{J}"
            print(f"\n=== Experiment: {scheme_name} | rounds={rounds}, local_steps={J} ===")

            # fresh global model for this combination
            global_model = CharLSTM(VOCAB_SIZE).to(device)
            global_state = global_model.state_dict()
            val_losses = []
            val_accs = []
            sel_counts = np.zeros(K, dtype=int)
            pvec = None

            t0 = time.time()
            for r in range(1, rounds + 1):
                # select clients (uniform or skewed)
                if scheme == 'uniform':
                    selected = random.sample(range(K), CLIENTS_PER_ROUND)
                    pvec = np.ones(K) / K
                else:
                    selected, pvec = sample_skewed_clients(K, C, gamma)
                    # defensive fallback if pvec invalid
                    if pvec is None or np.isnan(pvec).any() or pvec.sum() == 0:
                        pvec = np.ones(K) / K
                        selected = random.sample(range(K), CLIENTS_PER_ROUND)

                # update selection counts
                for s in selected:
                    sel_counts[s] += 1

                # logging participation summary
                if (r % log_every) == 0:
                    p_min = float(np.min(pvec)); p_max = float(np.max(pvec)); p_sum = float(np.sum(pvec))
                    topk_idx = np.argsort(pvec)[-topk:][::-1]
                    topk_vals = pvec[topk_idx]; topk_cum_sel = sel_counts[topk_idx]
                    print(f"[{scheme_name}] Round {r}/{rounds}  p_min={p_min:.4e}, p_max={p_max:.4e}, p_sum={p_sum:.4f}")


                    #print("  top-5 clients by p (client_id : p, cumulative_selected):")
                    #for cid, pv, cs in zip(topk_idx.tolist(), topk_vals.tolist(), topk_cum_sel.tolist()):
                        #print(f"    {cid:3d} : {pv:.6f} , selected_so_far={cs}")
                    print("  selected this round (first 20):", selected[:20], "(total selected:", len(selected), ")")
                    print("-" * 60)

                # local updates for selected clients (use J local steps)
                local_states = []
                local_sizes = []
                for cid in selected:
                    idx_list = client_indices_iid[cid]
                    if len(idx_list) == 0:
                        continue
                    s_state, s_size = client_update(global_state, idx_list, train_ds,
                                                    steps=J, batch_size=CLIENT_BATCH, lr=LR_LOCAL, device=device)
                    if s_state is None:
                        continue
                    local_states.append(s_state)
                    local_sizes.append(s_size)

                # aggregate (if any clients contributed)
                if len(local_states) == 0:
                    print("Warning: no client contributions this round; skipping aggregation.")
                else:
                    new_state = aggregate_states(local_states, local_sizes)
                    global_state = {k: new_state[k].to(device) for k in new_state}
                    global_model.load_state_dict(global_state)

                # evaluate
                val_loss, val_acc = evaluate(global_model, val_ds, device=device)
                val_losses.append(val_loss); val_accs.append(val_acc)

                if r % max(1, rounds//5) == 0 or r == 1 or r == rounds:
                    print(f"[{scheme_name}] Round {r}/{rounds}  val_acc={val_acc:.4f}  val_loss={val_loss:.4f}")

            t1 = time.time()
            elapsed = t1 - t0
            print(f"Finished {scheme_name} in {elapsed:.1f}s  final_val_acc={val_accs[-1]:.4f}")

            # save results for this run
            results[scheme_name] = {
                'rounds': rounds,
                'J': J,
                'scheme': scheme,
                'gamma': gamma,
                'val_losses': val_losses,
                'val_accs': val_accs,
                'sel_counts': sel_counts,
                'pvec_last_round': pvec,
                'time_s': elapsed
            }

            # quick plots per run (optional)
            plt.figure(figsize=(8,3))
            plt.subplot(1,2,1)
            plt.plot(val_accs, label='val_acc'); plt.title(f"{scheme_name} val_acc"); plt.xlabel('round')
            plt.subplot(1,2,2)
            plt.plot(val_losses, label='val_loss'); plt.title(f"{scheme_name} val_loss"); plt.xlabel('round')
            plt.tight_layout(); plt.show()

            if scheme == 'skewed':
                plt.figure(figsize=(8,3))
                plt.bar(np.arange(K), sel_counts)
                plt.title(f"Selection counts per client ({scheme_name})")
                plt.xlabel("client id"); plt.ylabel("times selected")
                plt.show()

# summary plot across all runs (example: validation accuracy)
plt.figure(figsize=(9,5))
for name, data in results.items():
    plt.plot(data['val_accs'], label=name)
plt.xlabel("round (per-run)"); plt.ylabel("val acc"); plt.legend(fontsize=8); plt.title("Validation accuracy across runs")
plt.show()
# ---------------- end cell ----------------
# Out:
# Loading Shakespeare dataset (this may take a few seconds)...
# Train size: 3803542, Val size: 422616, Vocab size: 80
# Example shard sizes (first 10): [38036, 38036, 38036, 38036, 38036, 38036, 38036, 38036, 38036, 38036]
#
# === Experiment: uniform_J1 | rounds=20, local_steps=1 ===
# [uniform_J1] Round 1/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [81, 14, 3, 94, 35, 31, 28, 17, 13, 86] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 1/20  val_acc=0.0074  val_loss=4.3828
# [uniform_J1] Round 2/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [94, 69, 11, 75, 54, 4, 3, 27, 29, 64] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 3/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [77, 3, 71, 25, 91, 83, 89, 69, 53, 28] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 4/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=1
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [57, 75, 35, 0, 97, 20, 89, 54, 43, 19] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 4/20  val_acc=0.0237  val_loss=4.3526
# [uniform_J1] Round 5/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [27, 97, 43, 13, 11, 48, 12, 45, 44, 77] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 6/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [33, 5, 93, 58, 68, 15, 48, 10, 70, 37] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 7/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [80, 79, 46, 73, 24, 90, 8, 5, 84, 29] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 8/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [98, 37, 10, 29, 12, 48, 35, 58, 81, 46] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 8/20  val_acc=0.0546  val_loss=4.3049
# [uniform_J1] Round 9/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [20, 47, 45, 26, 85, 34, 89, 87, 82, 9] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 10/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [77, 81, 21, 68, 93, 31, 20, 59, 48, 34] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 11/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=2
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [81, 88, 71, 28, 87, 41, 98, 99, 7, 29] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 12/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=2
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [4, 40, 51, 34, 8, 27, 72, 91, 83, 63] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 12/20  val_acc=0.1308  val_loss=4.2310
# [uniform_J1] Round 13/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=2
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=1
#   selected this round (first 20): [50, 82, 58, 18, 33, 17, 31, 95, 71, 68] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 14/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=2
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [33, 95, 74, 54, 51, 46, 28, 17, 65, 63] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 15/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=2
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=1
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [11, 96, 6, 14, 19, 80, 20, 87, 54, 76] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 16/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=2
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=1
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [8, 49, 48, 76, 59, 67, 32, 70, 1, 87] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 16/20  val_acc=0.1989  val_loss=4.0372
# [uniform_J1] Round 17/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=3
#      97 : 0.010000 , selected_so_far=2
#      96 : 0.010000 , selected_so_far=2
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [92, 14, 87, 68, 96, 34, 98, 82, 43, 37] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 18/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=3
#      97 : 0.010000 , selected_so_far=3
#      96 : 0.010000 , selected_so_far=2
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [55, 20, 58, 0, 92, 33, 64, 97, 22, 13] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 19/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=1
#      98 : 0.010000 , selected_so_far=3
#      97 : 0.010000 , selected_so_far=4
#      96 : 0.010000 , selected_so_far=2
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [80, 38, 81, 64, 77, 25, 19, 47, 97, 20] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 20/20  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=2
#      98 : 0.010000 , selected_so_far=3
#      97 : 0.010000 , selected_so_far=4
#      96 : 0.010000 , selected_so_far=2
#      95 : 0.010000 , selected_so_far=2
#   selected this round (first 20): [69, 99, 67, 0, 76, 41, 62, 2, 14, 46] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J1] Round 20/20  val_acc=0.1871  val_loss=3.5410
# Finished uniform_J1 in 1115.9s  final_val_acc=0.1871
# === Experiment: uniform_J4 | rounds=5, local_steps=4 ===
# [uniform_J4] Round 1/5  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=1
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [39, 30, 7, 72, 10, 93, 62, 8, 97, 68] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J4] Round 1/5  val_acc=0.0244  val_loss=4.3599
# [uniform_J4] Round 2/5  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=1
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [98, 16, 84, 60, 70, 21, 33, 67, 77, 54] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J4] Round 2/5  val_acc=0.0647  val_loss=4.3258
# [uniform_J4] Round 3/5  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=1
#      96 : 0.010000 , selected_so_far=1
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [27, 69, 96, 93, 88, 25, 91, 39, 51, 85] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J4] Round 3/5  val_acc=0.1304  val_loss=4.2770
# [uniform_J4] Round 4/5  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=1
#      96 : 0.010000 , selected_so_far=1
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [83, 47, 56, 66, 57, 15, 31, 28, 8, 43] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J4] Round 4/5  val_acc=0.1824  val_loss=4.1869
# [uniform_J4] Round 5/5  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=1
#      97 : 0.010000 , selected_so_far=1
#      96 : 0.010000 , selected_so_far=1
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [2, 75, 70, 29, 28, 0, 9, 90, 80, 7] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J4] Round 5/5  val_acc=0.1885  val_loss=3.9226
# Finished uniform_J4 in 274.9s  final_val_acc=0.1885
# === Experiment: uniform_J8 | rounds=3, local_steps=8 ===
# [uniform_J8] Round 1/3  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [29, 8, 4, 42, 9, 65, 30, 35, 85, 62] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J8] Round 1/3  val_acc=0.0919  val_loss=4.2983
# [uniform_J8] Round 2/3  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [27, 69, 16, 92, 73, 60, 31, 52, 24, 12] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J8] Round 2/3  val_acc=0.1950  val_loss=4.0647
# [uniform_J8] Round 3/3  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [12, 84, 55, 45, 54, 52, 59, 93, 6, 86] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J8] Round 3/3  val_acc=0.1871  val_loss=3.3432
# Finished uniform_J8 in 166.3s  final_val_acc=0.1871
# === Experiment: uniform_J16 | rounds=2, local_steps=16 ===
# [uniform_J16] Round 1/2  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [83, 82, 12, 7, 51, 93, 43, 13, 31, 24] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J16] Round 1/2  val_acc=0.1870  val_loss=4.0444
# [uniform_J16] Round 2/2  p_min=1.0000e-02, p_max=1.0000e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      99 : 0.010000 , selected_so_far=0
#      98 : 0.010000 , selected_so_far=0
#      97 : 0.010000 , selected_so_far=0
#      96 : 0.010000 , selected_so_far=0
#      95 : 0.010000 , selected_so_far=0
#   selected this round (first 20): [24, 68, 57, 17, 54, 23, 35, 59, 31, 9] (total selected: 10 )
# ------------------------------------------------------------
# [uniform_J16] Round 2/2  val_acc=0.1871  val_loss=3.1886
# Finished uniform_J16 in 111.4s  final_val_acc=0.1871
# === Experiment: skewed_gamma0.1_J1 | rounds=20, local_steps=1 ===
# [skewed_gamma0.1_J1] Round 1/20  p_min=2.9346e-24, p_max=1.3438e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      25 : 0.134377 , selected_so_far=1
#      17 : 0.119107 , selected_so_far=1
#      69 : 0.109029 , selected_so_far=1
#      66 : 0.071008 , selected_so_far=1
#      26 : 0.066814 , selected_so_far=1
#   selected this round (first 20): [np.int64(4), np.int64(25), np.int64(58), np.int64(69), np.int64(66), np.int64(26), np.int64(85), np.int64(89), np.int64(57), np.int64(17)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 1/20  val_acc=0.0535  val_loss=4.3446
# [skewed_gamma0.1_J1] Round 2/20  p_min=2.3321e-21, p_max=1.5757e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      40 : 0.157572 , selected_so_far=1
#      12 : 0.115043 , selected_so_far=1
#      44 : 0.102752 , selected_so_far=1
#       9 : 0.083091 , selected_so_far=1
#      91 : 0.076489 , selected_so_far=0
#   selected this round (first 20): [np.int64(11), np.int64(12), np.int64(83), np.int64(44), np.int64(9), np.int64(78), np.int64(86), np.int64(23), np.int64(99), np.int64(40)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 3/20  p_min=3.4287e-20, p_max=2.0636e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      25 : 0.206356 , selected_so_far=2
#      64 : 0.146446 , selected_so_far=0
#      13 : 0.098642 , selected_so_far=1
#      12 : 0.080949 , selected_so_far=2
#      61 : 0.058676 , selected_so_far=0
#   selected this round (first 20): [np.int64(25), np.int64(44), np.int64(36), np.int64(94), np.int64(41), np.int64(13), np.int64(12), np.int64(14), np.int64(29), np.int64(17)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 4/20  p_min=4.9517e-25, p_max=1.1454e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      20 : 0.114542 , selected_so_far=1
#      78 : 0.102897 , selected_so_far=2
#      52 : 0.075497 , selected_so_far=0
#      89 : 0.073798 , selected_so_far=1
#      36 : 0.065759 , selected_so_far=2
#   selected this round (first 20): [np.int64(78), np.int64(36), np.int64(61), np.int64(20), np.int64(29), np.int64(2), np.int64(19), np.int64(15), np.int64(33), np.int64(57)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 4/20  val_acc=0.1230  val_loss=4.3104
# [skewed_gamma0.1_J1] Round 5/20  p_min=4.5699e-19, p_max=2.3520e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      14 : 0.235205 , selected_so_far=2
#      46 : 0.075982 , selected_so_far=1
#      84 : 0.068150 , selected_so_far=1
#      57 : 0.067556 , selected_so_far=3
#      86 : 0.065666 , selected_so_far=2
#   selected this round (first 20): [np.int64(86), np.int64(92), np.int64(84), np.int64(67), np.int64(57), np.int64(14), np.int64(46), np.int64(43), np.int64(70), np.int64(56)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 6/20  p_min=9.0854e-24, p_max=1.7902e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      45 : 0.179020 , selected_so_far=1
#      90 : 0.121745 , selected_so_far=1
#      95 : 0.116762 , selected_so_far=1
#      30 : 0.111209 , selected_so_far=1
#      49 : 0.093084 , selected_so_far=1
#   selected this round (first 20): [np.int64(90), np.int64(45), np.int64(41), np.int64(99), np.int64(8), np.int64(95), np.int64(49), np.int64(76), np.int64(30), np.int64(54)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 7/20  p_min=5.6677e-25, p_max=1.7175e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      33 : 0.171745 , selected_so_far=2
#      52 : 0.104386 , selected_so_far=1
#       6 : 0.083960 , selected_so_far=1
#      41 : 0.079910 , selected_so_far=2
#      15 : 0.079674 , selected_so_far=2
#   selected this round (first 20): [np.int64(74), np.int64(33), np.int64(52), np.int64(6), np.int64(44), np.int64(12), np.int64(53), np.int64(90), np.int64(15), np.int64(7)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 8/20  p_min=4.1854e-21, p_max=2.6702e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      29 : 0.267019 , selected_so_far=3
#      42 : 0.257410 , selected_so_far=1
#      85 : 0.092446 , selected_so_far=2
#      60 : 0.065807 , selected_so_far=1
#      59 : 0.060994 , selected_so_far=1
#   selected this round (first 20): [np.int64(53), np.int64(85), np.int64(47), np.int64(42), np.int64(29), np.int64(60), np.int64(59), np.int64(16), np.int64(86), np.int64(26)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 8/20  val_acc=0.1855  val_loss=4.2516
# [skewed_gamma0.1_J1] Round 9/20  p_min=4.5455e-22, p_max=2.1011e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      33 : 0.210106 , selected_so_far=3
#      16 : 0.163804 , selected_so_far=2
#      53 : 0.079589 , selected_so_far=3
#      94 : 0.076873 , selected_so_far=2
#       1 : 0.076669 , selected_so_far=1
#   selected this round (first 20): [np.int64(1), np.int64(85), np.int64(16), np.int64(33), np.int64(27), np.int64(23), np.int64(94), np.int64(53), np.int64(18), np.int64(28)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 10/20  p_min=7.4129e-21, p_max=1.4060e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#       1 : 0.140598 , selected_so_far=2
#      66 : 0.126665 , selected_so_far=2
#       4 : 0.095660 , selected_so_far=2
#      32 : 0.075658 , selected_so_far=0
#      89 : 0.072273 , selected_so_far=1
#   selected this round (first 20): [np.int64(66), np.int64(88), np.int64(4), np.int64(1), np.int64(10), np.int64(79), np.int64(65), np.int64(99), np.int64(86), np.int64(45)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 11/20  p_min=3.7129e-24, p_max=1.8684e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      20 : 0.186837 , selected_so_far=2
#      89 : 0.137276 , selected_so_far=2
#      14 : 0.107383 , selected_so_far=3
#      47 : 0.090572 , selected_so_far=2
#      29 : 0.076645 , selected_so_far=4
#   selected this round (first 20): [np.int64(29), np.int64(47), np.int64(20), np.int64(93), np.int64(89), np.int64(38), np.int64(14), np.int64(36), np.int64(4), np.int64(65)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 12/20  p_min=2.0135e-40, p_max=1.9179e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      14 : 0.191787 , selected_so_far=4
#      53 : 0.176620 , selected_so_far=4
#      82 : 0.110968 , selected_so_far=1
#      87 : 0.087128 , selected_so_far=1
#      83 : 0.076230 , selected_so_far=2
#   selected this round (first 20): [np.int64(82), np.int64(14), np.int64(87), np.int64(25), np.int64(6), np.int64(11), np.int64(53), np.int64(83), np.int64(1), np.int64(27)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 12/20  val_acc=0.1868  val_loss=4.1501
# [skewed_gamma0.1_J1] Round 13/20  p_min=1.7529e-30, p_max=1.6247e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      47 : 0.162472 , selected_so_far=3
#       5 : 0.085539 , selected_so_far=1
#      25 : 0.083859 , selected_so_far=4
#      49 : 0.079281 , selected_so_far=2
#      50 : 0.064031 , selected_so_far=1
#   selected this round (first 20): [np.int64(65), np.int64(50), np.int64(24), np.int64(85), np.int64(49), np.int64(25), np.int64(47), np.int64(5), np.int64(17), np.int64(2)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 14/20  p_min=2.9515e-30, p_max=1.4288e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      12 : 0.142879 , selected_so_far=4
#      30 : 0.103110 , selected_so_far=1
#      66 : 0.076381 , selected_so_far=2
#      38 : 0.075327 , selected_so_far=2
#      73 : 0.071282 , selected_so_far=1
#   selected this round (first 20): [np.int64(12), np.int64(73), np.int64(11), np.int64(83), np.int64(5), np.int64(17), np.int64(23), np.int64(38), np.int64(28), np.int64(41)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 15/20  p_min=4.6545e-14, p_max=1.7115e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      81 : 0.171149 , selected_so_far=1
#      32 : 0.115582 , selected_so_far=1
#       2 : 0.112342 , selected_so_far=3
#      34 : 0.091863 , selected_so_far=1
#       4 : 0.079774 , selected_so_far=4
#   selected this round (first 20): [np.int64(81), np.int64(76), np.int64(39), np.int64(60), np.int64(34), np.int64(4), np.int64(25), np.int64(32), np.int64(11), np.int64(2)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 16/20  p_min=4.6371e-19, p_max=1.3370e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      46 : 0.133700 , selected_so_far=2
#      78 : 0.103779 , selected_so_far=3
#      76 : 0.096392 , selected_so_far=3
#      85 : 0.095331 , selected_so_far=5
#      86 : 0.079925 , selected_so_far=5
#   selected this round (first 20): [np.int64(8), np.int64(58), np.int64(46), np.int64(85), np.int64(51), np.int64(78), np.int64(72), np.int64(76), np.int64(79), np.int64(86)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 16/20  val_acc=0.1871  val_loss=3.8766
# [skewed_gamma0.1_J1] Round 17/20  p_min=1.9176e-33, p_max=1.2917e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      62 : 0.129165 , selected_so_far=1
#      10 : 0.102046 , selected_so_far=2
#      66 : 0.093512 , selected_so_far=3
#      74 : 0.075850 , selected_so_far=2
#      63 : 0.073105 , selected_so_far=1
#   selected this round (first 20): [np.int64(74), np.int64(62), np.int64(63), np.int64(82), np.int64(55), np.int64(40), np.int64(1), np.int64(66), np.int64(10), np.int64(57)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 18/20  p_min=1.7592e-19, p_max=2.0649e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#       1 : 0.206491 , selected_so_far=5
#      60 : 0.186482 , selected_so_far=3
#       7 : 0.134891 , selected_so_far=2
#      31 : 0.065608 , selected_so_far=1
#       6 : 0.065421 , selected_so_far=3
#   selected this round (first 20): [np.int64(1), np.int64(46), np.int64(60), np.int64(6), np.int64(7), np.int64(53), np.int64(13), np.int64(42), np.int64(78), np.int64(31)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 19/20  p_min=2.9463e-20, p_max=2.0515e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      11 : 0.205146 , selected_so_far=5
#      42 : 0.135828 , selected_so_far=3
#      68 : 0.111143 , selected_so_far=1
#      18 : 0.070653 , selected_so_far=2
#      61 : 0.055859 , selected_so_far=1
#   selected this round (first 20): [np.int64(68), np.int64(42), np.int64(52), np.int64(18), np.int64(43), np.int64(29), np.int64(11), np.int64(47), np.int64(20), np.int64(84)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 20/20  p_min=1.8619e-18, p_max=3.7548e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      83 : 0.375482 , selected_so_far=4
#      38 : 0.145421 , selected_so_far=3
#      74 : 0.105345 , selected_so_far=3
#      84 : 0.082604 , selected_so_far=3
#      78 : 0.077837 , selected_so_far=5
#   selected this round (first 20): [np.int64(84), np.int64(42), np.int64(83), np.int64(38), np.int64(74), np.int64(43), np.int64(78), np.int64(52), np.int64(62), np.int64(73)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J1] Round 20/20  val_acc=0.1871  val_loss=3.4876
# Finished skewed_gamma0.1_J1 in 1098.0s  final_val_acc=0.1871
# === Experiment: skewed_gamma0.1_J4 | rounds=5, local_steps=4 ===
# [skewed_gamma0.1_J4] Round 1/5  p_min=3.0093e-20, p_max=1.7850e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      57 : 0.178503 , selected_so_far=1
#      72 : 0.096528 , selected_so_far=1
#       5 : 0.082859 , selected_so_far=1
#      88 : 0.077286 , selected_so_far=1
#      80 : 0.076225 , selected_so_far=0
#   selected this round (first 20): [np.int64(72), np.int64(57), np.int64(87), np.int64(6), np.int64(88), np.int64(5), np.int64(90), np.int64(76), np.int64(71), np.int64(48)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J4] Round 1/5  val_acc=0.0322  val_loss=4.3341
# [skewed_gamma0.1_J4] Round 2/5  p_min=2.3670e-38, p_max=2.7311e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      37 : 0.273105 , selected_so_far=1
#      35 : 0.173719 , selected_so_far=1
#       4 : 0.097955 , selected_so_far=1
#      57 : 0.053609 , selected_so_far=2
#      72 : 0.051466 , selected_so_far=1
#   selected this round (first 20): [np.int64(80), np.int64(4), np.int64(37), np.int64(17), np.int64(35), np.int64(21), np.int64(85), np.int64(34), np.int64(52), np.int64(57)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J4] Round 2/5  val_acc=0.1427  val_loss=4.2660
# [skewed_gamma0.1_J4] Round 3/5  p_min=4.0743e-32, p_max=1.1682e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      35 : 0.116815 , selected_so_far=2
#      40 : 0.108278 , selected_so_far=1
#      79 : 0.097050 , selected_so_far=1
#      95 : 0.089489 , selected_so_far=1
#      28 : 0.081941 , selected_so_far=1
#   selected this round (first 20): [np.int64(29), np.int64(95), np.int64(5), np.int64(38), np.int64(46), np.int64(40), np.int64(28), np.int64(79), np.int64(35), np.int64(11)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J4] Round 3/5  val_acc=0.1865  val_loss=4.1279
# [skewed_gamma0.1_J4] Round 4/5  p_min=6.6270e-24, p_max=1.6999e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      32 : 0.169994 , selected_so_far=1
#      56 : 0.089510 , selected_so_far=1
#      86 : 0.078581 , selected_so_far=0
#      88 : 0.072450 , selected_so_far=1
#      99 : 0.057411 , selected_so_far=1
#   selected this round (first 20): [np.int64(23), np.int64(99), np.int64(54), np.int64(3), np.int64(27), np.int64(32), np.int64(81), np.int64(84), np.int64(28), np.int64(56)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J4] Round 4/5  val_acc=0.1870  val_loss=3.7361
# [skewed_gamma0.1_J4] Round 5/5  p_min=1.0328e-21, p_max=1.9019e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      51 : 0.190190 , selected_so_far=1
#      34 : 0.178880 , selected_so_far=2
#      26 : 0.135394 , selected_so_far=1
#      24 : 0.107913 , selected_so_far=1
#      98 : 0.078516 , selected_so_far=1
#   selected this round (first 20): [np.int64(24), np.int64(55), np.int64(26), np.int64(51), np.int64(34), np.int64(99), np.int64(98), np.int64(2), np.int64(78), np.int64(80)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J4] Round 5/5  val_acc=0.1871  val_loss=3.3674
# Finished skewed_gamma0.1_J4 in 276.3s  final_val_acc=0.1871
# === Experiment: skewed_gamma0.1_J8 | rounds=3, local_steps=8 ===
# [skewed_gamma0.1_J8] Round 1/3  p_min=2.7569e-19, p_max=2.5111e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      86 : 0.251110 , selected_so_far=1
#      44 : 0.101125 , selected_so_far=0
#      52 : 0.089589 , selected_so_far=1
#      93 : 0.062866 , selected_so_far=1
#       9 : 0.051548 , selected_so_far=1
#   selected this round (first 20): [np.int64(86), np.int64(18), np.int64(40), np.int64(52), np.int64(83), np.int64(9), np.int64(0), np.int64(93), np.int64(26), np.int64(82)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J8] Round 1/3  val_acc=0.1760  val_loss=4.2873
# [skewed_gamma0.1_J8] Round 2/3  p_min=4.7744e-23, p_max=2.0497e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      62 : 0.204971 , selected_so_far=1
#      76 : 0.095252 , selected_so_far=1
#       1 : 0.094811 , selected_so_far=1
#       4 : 0.091911 , selected_so_far=1
#      94 : 0.082647 , selected_so_far=1
#   selected this round (first 20): [np.int64(1), np.int64(62), np.int64(53), np.int64(76), np.int64(4), np.int64(87), np.int64(15), np.int64(94), np.int64(42), np.int64(14)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J8] Round 2/3  val_acc=0.1871  val_loss=4.0724
# [skewed_gamma0.1_J8] Round 3/3  p_min=1.3335e-25, p_max=2.6903e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#       2 : 0.269034 , selected_so_far=1
#      48 : 0.242187 , selected_so_far=1
#      29 : 0.112766 , selected_so_far=1
#      49 : 0.072849 , selected_so_far=1
#      94 : 0.069656 , selected_so_far=2
#   selected this round (first 20): [np.int64(49), np.int64(2), np.int64(21), np.int64(48), np.int64(10), np.int64(55), np.int64(12), np.int64(94), np.int64(89), np.int64(29)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J8] Round 3/3  val_acc=0.1871  val_loss=3.3312
# Finished skewed_gamma0.1_J8 in 165.9s  final_val_acc=0.1871
# === Experiment: skewed_gamma0.1_J16 | rounds=2, local_steps=16 ===
# [skewed_gamma0.1_J16] Round 1/2  p_min=5.2850e-23, p_max=1.2998e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      72 : 0.129979 , selected_so_far=1
#      27 : 0.125079 , selected_so_far=1
#      29 : 0.086236 , selected_so_far=0
#      46 : 0.084511 , selected_so_far=1
#      94 : 0.079221 , selected_so_far=0
#   selected this round (first 20): [np.int64(24), np.int64(60), np.int64(27), np.int64(4), np.int64(72), np.int64(6), np.int64(62), np.int64(97), np.int64(46), np.int64(16)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J16] Round 1/2  val_acc=0.1892  val_loss=4.1408
# [skewed_gamma0.1_J16] Round 2/2  p_min=7.1059e-24, p_max=1.7462e-01, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      11 : 0.174620 , selected_so_far=1
#      53 : 0.120912 , selected_so_far=0
#      63 : 0.092478 , selected_so_far=1
#      12 : 0.070160 , selected_so_far=1
#      28 : 0.061669 , selected_so_far=1
#   selected this round (first 20): [np.int64(24), np.int64(44), np.int64(38), np.int64(28), np.int64(63), np.int64(86), np.int64(11), np.int64(12), np.int64(39), np.int64(78)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma0.1_J16] Round 2/2  val_acc=0.1871  val_loss=3.2172
# Finished skewed_gamma0.1_J16 in 111.1s  final_val_acc=0.1871
# === Experiment: skewed_gamma1.0_J1 | rounds=20, local_steps=1 ===
# [skewed_gamma1.0_J1] Round 1/20  p_min=1.3690e-05, p_max=6.8386e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      86 : 0.068386 , selected_so_far=0
#      73 : 0.049946 , selected_so_far=0
#      76 : 0.047296 , selected_so_far=1
#      94 : 0.035365 , selected_so_far=0
#      56 : 0.031207 , selected_so_far=1
#   selected this round (first 20): [np.int64(72), np.int64(22), np.int64(51), np.int64(34), np.int64(76), np.int64(56), np.int64(99), np.int64(8), np.int64(41), np.int64(57)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 1/20  val_acc=0.0702  val_loss=4.3535
# [skewed_gamma1.0_J1] Round 2/20  p_min=1.2676e-04, p_max=3.6333e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      40 : 0.036333 , selected_so_far=0
#      57 : 0.033819 , selected_so_far=1
#      41 : 0.033150 , selected_so_far=1
#      14 : 0.032024 , selected_so_far=0
#      87 : 0.031136 , selected_so_far=1
#   selected this round (first 20): [np.int64(35), np.int64(46), np.int64(92), np.int64(90), np.int64(21), np.int64(38), np.int64(12), np.int64(50), np.int64(87), np.int64(86)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 3/20  p_min=4.0988e-05, p_max=4.2634e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      18 : 0.042634 , selected_so_far=1
#      66 : 0.034947 , selected_so_far=0
#      69 : 0.034382 , selected_so_far=0
#      41 : 0.033002 , selected_so_far=1
#      97 : 0.032849 , selected_so_far=0
#   selected this round (first 20): [np.int64(10), np.int64(91), np.int64(61), np.int64(67), np.int64(90), np.int64(37), np.int64(65), np.int64(3), np.int64(18), np.int64(84)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 4/20  p_min=2.6661e-06, p_max=4.5965e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      24 : 0.045965 , selected_so_far=1
#      19 : 0.035493 , selected_so_far=1
#      99 : 0.035338 , selected_so_far=1
#      57 : 0.031748 , selected_so_far=2
#      41 : 0.029841 , selected_so_far=2
#   selected this round (first 20): [np.int64(57), np.int64(24), np.int64(10), np.int64(3), np.int64(88), np.int64(41), np.int64(69), np.int64(93), np.int64(19), np.int64(49)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 4/20  val_acc=0.1500  val_loss=4.3270
# [skewed_gamma1.0_J1] Round 5/20  p_min=5.3020e-04, p_max=4.7589e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      61 : 0.047589 , selected_so_far=1
#      37 : 0.032586 , selected_so_far=1
#      84 : 0.029243 , selected_so_far=2
#      25 : 0.028958 , selected_so_far=0
#      14 : 0.028839 , selected_so_far=0
#   selected this round (first 20): [np.int64(58), np.int64(54), np.int64(67), np.int64(89), np.int64(85), np.int64(23), np.int64(13), np.int64(29), np.int64(84), np.int64(94)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 6/20  p_min=4.3307e-06, p_max=4.8978e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      89 : 0.048978 , selected_so_far=1
#      69 : 0.041287 , selected_so_far=1
#      84 : 0.036740 , selected_so_far=2
#      45 : 0.035820 , selected_so_far=0
#      93 : 0.032072 , selected_so_far=2
#   selected this round (first 20): [np.int64(21), np.int64(77), np.int64(17), np.int64(62), np.int64(87), np.int64(93), np.int64(53), np.int64(33), np.int64(23), np.int64(2)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 7/20  p_min=2.6616e-04, p_max=4.9661e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      45 : 0.049661 , selected_so_far=0
#      19 : 0.047885 , selected_so_far=2
#      50 : 0.042513 , selected_so_far=1
#      70 : 0.040284 , selected_so_far=0
#      20 : 0.033270 , selected_so_far=0
#   selected this round (first 20): [np.int64(19), np.int64(21), np.int64(12), np.int64(55), np.int64(5), np.int64(26), np.int64(64), np.int64(47), np.int64(23), np.int64(61)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 8/20  p_min=1.3235e-04, p_max=7.0224e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#       6 : 0.070224 , selected_so_far=0
#      62 : 0.055630 , selected_so_far=2
#      94 : 0.046664 , selected_so_far=2
#      38 : 0.033532 , selected_so_far=1
#      56 : 0.030141 , selected_so_far=1
#   selected this round (first 20): [np.int64(65), np.int64(94), np.int64(39), np.int64(62), np.int64(45), np.int64(61), np.int64(44), np.int64(16), np.int64(50), np.int64(52)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 8/20  val_acc=0.1798  val_loss=4.2818
# [skewed_gamma1.0_J1] Round 9/20  p_min=1.3238e-05, p_max=6.1400e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      39 : 0.061400 , selected_so_far=1
#      36 : 0.047665 , selected_so_far=1
#      74 : 0.042337 , selected_so_far=0
#      59 : 0.036545 , selected_so_far=1
#       7 : 0.025999 , selected_so_far=0
#   selected this round (first 20): [np.int64(60), np.int64(2), np.int64(59), np.int64(71), np.int64(44), np.int64(36), np.int64(28), np.int64(65), np.int64(82), np.int64(33)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 10/20  p_min=7.9321e-06, p_max=5.7333e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      30 : 0.057333 , selected_so_far=1
#      49 : 0.042534 , selected_so_far=1
#       7 : 0.033579 , selected_so_far=0
#      45 : 0.030952 , selected_so_far=1
#      10 : 0.027853 , selected_so_far=2
#   selected this round (first 20): [np.int64(46), np.int64(63), np.int64(23), np.int64(30), np.int64(2), np.int64(74), np.int64(87), np.int64(47), np.int64(43), np.int64(3)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 11/20  p_min=8.6079e-06, p_max=5.1543e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      20 : 0.051543 , selected_so_far=1
#      83 : 0.043420 , selected_so_far=1
#       2 : 0.034761 , selected_so_far=3
#      44 : 0.034619 , selected_so_far=3
#      35 : 0.033879 , selected_so_far=1
#   selected this round (first 20): [np.int64(51), np.int64(90), np.int64(7), np.int64(83), np.int64(20), np.int64(36), np.int64(31), np.int64(37), np.int64(12), np.int64(44)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 12/20  p_min=2.4035e-05, p_max=4.9496e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      13 : 0.049496 , selected_so_far=1
#      78 : 0.041462 , selected_so_far=0
#      58 : 0.030679 , selected_so_far=1
#      32 : 0.028839 , selected_so_far=1
#      56 : 0.027478 , selected_so_far=1
#   selected this round (first 20): [np.int64(29), np.int64(32), np.int64(11), np.int64(18), np.int64(47), np.int64(92), np.int64(9), np.int64(77), np.int64(70), np.int64(7)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 12/20  val_acc=0.1870  val_loss=4.2077
# [skewed_gamma1.0_J1] Round 13/20  p_min=1.4513e-04, p_max=4.3099e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      98 : 0.043099 , selected_so_far=1
#      37 : 0.037804 , selected_so_far=2
#      90 : 0.036195 , selected_so_far=3
#      36 : 0.035038 , selected_so_far=2
#      61 : 0.032688 , selected_so_far=4
#   selected this round (first 20): [np.int64(3), np.int64(86), np.int64(61), np.int64(19), np.int64(50), np.int64(81), np.int64(83), np.int64(34), np.int64(98), np.int64(64)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 14/20  p_min=2.8623e-06, p_max=6.4479e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      69 : 0.064479 , selected_so_far=2
#      18 : 0.041671 , selected_so_far=3
#      23 : 0.039103 , selected_so_far=4
#      46 : 0.038771 , selected_so_far=2
#      30 : 0.035516 , selected_so_far=1
#   selected this round (first 20): [np.int64(33), np.int64(45), np.int64(47), np.int64(29), np.int64(27), np.int64(69), np.int64(82), np.int64(18), np.int64(13), np.int64(84)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 15/20  p_min=1.1975e-04, p_max=4.4258e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      33 : 0.044258 , selected_so_far=3
#      27 : 0.042864 , selected_so_far=1
#      57 : 0.041643 , selected_so_far=2
#      66 : 0.038936 , selected_so_far=0
#      26 : 0.028399 , selected_so_far=1
#   selected this round (first 20): [np.int64(8), np.int64(76), np.int64(14), np.int64(90), np.int64(84), np.int64(42), np.int64(70), np.int64(58), np.int64(75), np.int64(38)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 16/20  p_min=4.0686e-05, p_max=4.6495e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      93 : 0.046495 , selected_so_far=2
#      77 : 0.043070 , selected_so_far=2
#      52 : 0.040507 , selected_so_far=1
#      10 : 0.037604 , selected_so_far=2
#      58 : 0.034936 , selected_so_far=2
#   selected this round (first 20): [np.int64(94), np.int64(18), np.int64(48), np.int64(1), np.int64(62), np.int64(42), np.int64(22), np.int64(15), np.int64(64), np.int64(43)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 16/20  val_acc=0.1871  val_loss=4.0253
# [skewed_gamma1.0_J1] Round 17/20  p_min=3.6486e-06, p_max=4.8252e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      20 : 0.048252 , selected_so_far=1
#      52 : 0.045923 , selected_so_far=1
#      51 : 0.033931 , selected_so_far=3
#      59 : 0.031863 , selected_so_far=1
#      16 : 0.029118 , selected_so_far=1
#   selected this round (first 20): [np.int64(39), np.int64(51), np.int64(76), np.int64(37), np.int64(38), np.int64(10), np.int64(93), np.int64(61), np.int64(40), np.int64(68)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 18/20  p_min=9.7636e-05, p_max=5.6278e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      64 : 0.056278 , selected_so_far=4
#      56 : 0.050785 , selected_so_far=1
#      60 : 0.032372 , selected_so_far=1
#      59 : 0.030594 , selected_so_far=1
#      10 : 0.025607 , selected_so_far=3
#   selected this round (first 20): [np.int64(53), np.int64(18), np.int64(11), np.int64(81), np.int64(43), np.int64(40), np.int64(3), np.int64(50), np.int64(55), np.int64(64)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 19/20  p_min=1.1478e-04, p_max=4.9716e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      68 : 0.049716 , selected_so_far=1
#      29 : 0.040712 , selected_so_far=4
#      87 : 0.039140 , selected_so_far=3
#       3 : 0.036353 , selected_so_far=5
#      33 : 0.032508 , selected_so_far=3
#   selected this round (first 20): [np.int64(14), np.int64(42), np.int64(22), np.int64(29), np.int64(30), np.int64(52), np.int64(43), np.int64(96), np.int64(98), np.int64(28)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 20/20  p_min=4.7806e-05, p_max=5.3989e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      43 : 0.053989 , selected_so_far=5
#      25 : 0.052852 , selected_so_far=1
#      56 : 0.031454 , selected_so_far=1
#      68 : 0.029595 , selected_so_far=2
#      96 : 0.028291 , selected_so_far=1
#   selected this round (first 20): [np.int64(37), np.int64(25), np.int64(59), np.int64(43), np.int64(3), np.int64(33), np.int64(80), np.int64(67), np.int64(69), np.int64(68)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J1] Round 20/20  val_acc=0.1871  val_loss=3.5246
# Finished skewed_gamma1.0_J1 in 1089.9s  final_val_acc=0.1871
# === Experiment: skewed_gamma1.0_J4 | rounds=5, local_steps=4 ===
# [skewed_gamma1.0_J4] Round 1/5  p_min=5.4765e-05, p_max=4.4099e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      21 : 0.044099 , selected_so_far=1
#       4 : 0.040376 , selected_so_far=0
#      41 : 0.040159 , selected_so_far=0
#      11 : 0.029452 , selected_so_far=0
#      99 : 0.029318 , selected_so_far=1
#   selected this round (first 20): [np.int64(78), np.int64(55), np.int64(21), np.int64(18), np.int64(29), np.int64(43), np.int64(23), np.int64(49), np.int64(15), np.int64(99)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J4] Round 1/5  val_acc=0.0240  val_loss=4.3539
# [skewed_gamma1.0_J4] Round 2/5  p_min=3.3060e-04, p_max=6.2974e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      30 : 0.062974 , selected_so_far=1
#      89 : 0.042385 , selected_so_far=0
#      44 : 0.040486 , selected_so_far=0
#      50 : 0.033193 , selected_so_far=0
#      57 : 0.032622 , selected_so_far=1
#   selected this round (first 20): [np.int64(91), np.int64(39), np.int64(57), np.int64(78), np.int64(34), np.int64(69), np.int64(13), np.int64(30), np.int64(17), np.int64(79)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J4] Round 2/5  val_acc=0.0521  val_loss=4.3021
# [skewed_gamma1.0_J4] Round 3/5  p_min=4.7032e-07, p_max=3.7998e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#       9 : 0.037998 , selected_so_far=0
#      17 : 0.029058 , selected_so_far=1
#      34 : 0.029030 , selected_so_far=2
#      56 : 0.028660 , selected_so_far=1
#      89 : 0.028639 , selected_so_far=0
#   selected this round (first 20): [np.int64(82), np.int64(56), np.int64(91), np.int64(93), np.int64(7), np.int64(34), np.int64(2), np.int64(26), np.int64(52), np.int64(88)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J4] Round 3/5  val_acc=0.1551  val_loss=4.2164
# [skewed_gamma1.0_J4] Round 4/5  p_min=2.2074e-04, p_max=3.4395e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      75 : 0.034395 , selected_so_far=1
#      79 : 0.033261 , selected_so_far=2
#      62 : 0.033156 , selected_so_far=0
#      13 : 0.030458 , selected_so_far=1
#       6 : 0.030367 , selected_so_far=0
#   selected this round (first 20): [np.int64(75), np.int64(19), np.int64(85), np.int64(66), np.int64(44), np.int64(15), np.int64(93), np.int64(76), np.int64(32), np.int64(79)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J4] Round 4/5  val_acc=0.1859  val_loss=4.0106
# [skewed_gamma1.0_J4] Round 5/5  p_min=7.8983e-05, p_max=6.3873e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      61 : 0.063873 , selected_so_far=1
#      15 : 0.062586 , selected_so_far=3
#       7 : 0.036190 , selected_so_far=2
#      60 : 0.028893 , selected_so_far=0
#      94 : 0.028886 , selected_so_far=0
#   selected this round (first 20): [np.int64(82), np.int64(15), np.int64(61), np.int64(22), np.int64(63), np.int64(16), np.int64(0), np.int64(13), np.int64(7), np.int64(19)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J4] Round 5/5  val_acc=0.1871  val_loss=3.4900
# Finished skewed_gamma1.0_J4 in 274.4s  final_val_acc=0.1871
# === Experiment: skewed_gamma1.0_J8 | rounds=3, local_steps=8 ===
# [skewed_gamma1.0_J8] Round 1/3  p_min=5.6261e-05, p_max=4.4818e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      85 : 0.044818 , selected_so_far=0
#      33 : 0.038419 , selected_so_far=0
#       3 : 0.035126 , selected_so_far=1
#      55 : 0.031123 , selected_so_far=0
#      22 : 0.030815 , selected_so_far=0
#   selected this round (first 20): [np.int64(41), np.int64(31), np.int64(12), np.int64(16), np.int64(3), np.int64(92), np.int64(14), np.int64(91), np.int64(76), np.int64(67)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J8] Round 1/3  val_acc=0.1008  val_loss=4.3230
# [skewed_gamma1.0_J8] Round 2/3  p_min=2.3522e-04, p_max=5.1029e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      60 : 0.051029 , selected_so_far=0
#      30 : 0.036213 , selected_so_far=1
#      63 : 0.035133 , selected_so_far=0
#      82 : 0.034650 , selected_so_far=0
#      58 : 0.029403 , selected_so_far=1
#   selected this round (first 20): [np.int64(54), np.int64(58), np.int64(92), np.int64(15), np.int64(61), np.int64(75), np.int64(24), np.int64(27), np.int64(3), np.int64(30)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J8] Round 2/3  val_acc=0.1993  val_loss=4.1099
# [skewed_gamma1.0_J8] Round 3/3  p_min=2.8150e-05, p_max=5.1141e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      92 : 0.051141 , selected_so_far=2
#      97 : 0.037760 , selected_so_far=0
#      25 : 0.036503 , selected_so_far=1
#      60 : 0.036171 , selected_so_far=0
#      11 : 0.031588 , selected_so_far=0
#   selected this round (first 20): [np.int64(25), np.int64(69), np.int64(84), np.int64(99), np.int64(21), np.int64(35), np.int64(20), np.int64(46), np.int64(88), np.int64(54)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J8] Round 3/3  val_acc=0.1871  val_loss=3.3228
# Finished skewed_gamma1.0_J8 in 165.4s  final_val_acc=0.1871
# === Experiment: skewed_gamma1.0_J16 | rounds=2, local_steps=16 ===
# [skewed_gamma1.0_J16] Round 1/2  p_min=4.6032e-05, p_max=4.9405e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      57 : 0.049405 , selected_so_far=1
#       1 : 0.048705 , selected_so_far=1
#      65 : 0.043662 , selected_so_far=1
#      32 : 0.039254 , selected_so_far=0
#      75 : 0.032965 , selected_so_far=0
#   selected this round (first 20): [np.int64(2), np.int64(37), np.int64(65), np.int64(55), np.int64(39), np.int64(57), np.int64(35), np.int64(88), np.int64(1), np.int64(64)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J16] Round 1/2  val_acc=0.1945  val_loss=4.0801
# [skewed_gamma1.0_J16] Round 2/2  p_min=2.4834e-06, p_max=7.8462e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      41 : 0.078462 , selected_so_far=0
#      85 : 0.038482 , selected_so_far=1
#      86 : 0.032434 , selected_so_far=0
#      92 : 0.031009 , selected_so_far=1
#      54 : 0.028762 , selected_so_far=0
#   selected this round (first 20): [np.int64(36), np.int64(32), np.int64(1), np.int64(85), np.int64(42), np.int64(43), np.int64(11), np.int64(88), np.int64(92), np.int64(97)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma1.0_J16] Round 2/2  val_acc=0.1871  val_loss=3.1809
# Finished skewed_gamma1.0_J16 in 110.6s  final_val_acc=0.1871
# === Experiment: skewed_gamma10.0_J1 | rounds=20, local_steps=1 ===
# [skewed_gamma10.0_J1] Round 1/20  p_min=4.1804e-03, p_max=1.8859e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      25 : 0.018859 , selected_so_far=0
#      85 : 0.018077 , selected_so_far=0
#      61 : 0.017871 , selected_so_far=0
#      74 : 0.017461 , selected_so_far=0
#      37 : 0.017362 , selected_so_far=0
#   selected this round (first 20): [np.int64(67), np.int64(72), np.int64(96), np.int64(27), np.int64(2), np.int64(54), np.int64(70), np.int64(79), np.int64(20), np.int64(50)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma10.0_J1] Round 1/20  val_acc=0.0138  val_loss=4.3512
# [skewed_gamma10.0_J1] Round 2/20  p_min=2.9146e-03, p_max=2.1064e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      50 : 0.021064 , selected_so_far=1
#      18 : 0.019240 , selected_so_far=0
#      82 : 0.018477 , selected_so_far=0
#      68 : 0.018144 , selected_so_far=0
#      27 : 0.017799 , selected_so_far=1
#   selected this round (first 20): [np.int64(79), np.int64(53), np.int64(58), np.int64(85), np.int64(80), np.int64(12), np.int64(71), np.int64(43), np.int64(29), np.int64(4)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma10.0_J1] Round 3/20  p_min=3.8859e-03, p_max=1.9304e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      65 : 0.019304 , selected_so_far=1
#      44 : 0.018728 , selected_so_far=0
#      15 : 0.018027 , selected_so_far=0
#      79 : 0.016834 , selected_so_far=2
#      18 : 0.015648 , selected_so_far=0
#   selected this round (first 20): [np.int64(65), np.int64(13), np.int64(54), np.int64(31), np.int64(94), np.int64(75), np.int64(97), np.int64(4), np.int64(30), np.int64(21)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma10.0_J1] Round 4/20  p_min=3.5316e-03, p_max=1.9222e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      76 : 0.019222 , selected_so_far=1
#      89 : 0.019019 , selected_so_far=0
#      18 : 0.017284 , selected_so_far=0
#      70 : 0.016008 , selected_so_far=1
#      28 : 0.015861 , selected_so_far=0
#   selected this round (first 20): [np.int64(5), np.int64(91), np.int64(21), np.int64(99), np.int64(17), np.int64(76), np.int64(8), np.int64(86), np.int64(84), np.int64(40)] (total selected: 10 )
# ------------------------------------------------------------
# [skewed_gamma10.0_J1] Round 4/20  val_acc=0.0555  val_loss=4.3264
# [skewed_gamma10.0_J1] Round 5/20  p_min=4.1984e-03, p_max=1.8278e-02, p_sum=1.0000
#   top-5 clients by p (client_id : p, cumulative_selected):
#      11 : 0.018278 , selected_so_far=0
#      25 : 0.017041 , selected_so_far=0
#      37 : 0.015757 , selected_so_far=0
#      10 : 0.015349 , selected_so_far=1
#      33 : 0.015115 , selected_so_far=0
#   selected this round (first 20): [np.int64(3), np.int64(71), np.int64(91), np.int64(78), np.int64(57), np.int64(65), np.int64(99), np.int64(10), np.int64(27), np.int64(60)] (total selected: 10 )
# ------------------------------------------------------------

# %%
# ---------------- Nc experiments cell ----------------
import math, time
import pandas as pd

# Experiment parameters (can be tuned)
Nc_values = [1, 5, 10, 50]      # non-iid label counts per client
J_values = [1, 4, 8, 16]           # local steps per selected client
C = 0.1                         # fraction of clients per round
m = max(1, int(math.ceil(C * K)))   # clients per round (should be 10)
base_rounds_ref = 200            # reference rounds used to compute total local updates in baseline (50 rounds at J=4)

# storage
nc_results = {}   # (Nc_or_iid, J) -> dict with summary and full history

print(f"Running Nc experiments: K={K}, clients/round={m}; base reference rounds={base_rounds_ref}")

for Nc in (Nc_values + ['iid']):
    # Build shards
    if Nc == 'iid':
        shards = client_indices_iid
        label_str = 'iid'
    else:
        # create_label_shards(train_dataset, idx2char, K, Nc)
        shards, clients_allowed = create_label_shards(train_ds, idx2char, K, Nc, seed=SEED)
        label_str = f'Nc{Nc}'
    print("\n--- Shard type:", label_str, " ---")
    for J in J_values:
        # compute rounds so total local updates ~ constant across J
        # base_total_updates = base_rounds_ref * m * 4  -> dividing by (m*J) gives rounds = ceil((base_rounds_ref * 4) / J)
        R = max(1, math.ceil((base_rounds_ref * 4) / J))
        print(f"Running J={J} local steps => rounds R={R}")
        # fresh global model for this run
        global_model = CharLSTM(VOCAB_SIZE).to(DEVICE)
        global_state = global_model.state_dict()
        val_losses = []
        val_accs = []
        sel_counts = np.zeros(K, dtype=int)

        t0 = time.time()
        for r in range(1, R + 1):
            # Uniform sampling of clients each round (per your spec for this comparison)
            selected = random.sample(range(K), m)
            for s in selected:
                sel_counts[s] += 1

            # local updates
            local_states = []
            local_sizes = []
            for cid in selected:
                idx_list = shards[cid]
                if len(idx_list) == 0:
                    # skip empty client shards
                    continue
                s_state, s_size = client_update(global_state, idx_list, train_ds,
                                                steps=J, batch_size=CLIENT_BATCH, lr=LR_LOCAL, device=DEVICE)
                if s_state is None:
                    continue
                local_states.append(s_state)
                local_sizes.append(s_size)

            # If no client contributed (unlikely), skip aggregation
            if len(local_states) == 0:
                print("Warning: no client contributions this round, skipping aggregation.")
            else:
                # aggregate and update global
                new_state = aggregate_states(local_states, local_sizes)
                # move to device
                global_state = {k: new_state[k].to(DEVICE) for k in new_state}
                global_model.load_state_dict(global_state)

            # evaluate on validation
            val_loss, val_acc = evaluate(global_model, val_ds, device=DEVICE)
            val_losses.append(val_loss)
            val_accs.append(val_acc)

            if (r % max(1, R//5) == 0) or r == 1 or r == R:
                print(f"[{label_str} J={J}] Round {r}/{R}: val_acc={val_acc:.4f}, val_loss={val_loss:.4f}")

        t1 = time.time()
        elapsed = t1 - t0
        final_acc = val_accs[-1] if len(val_accs) > 0 else None

        # store results
        nc_results[(label_str, J)] = {
            'rounds': R,
            'val_losses': val_losses,
            'val_accs': val_accs,
            'final_acc': final_acc,
            'sel_counts': sel_counts,
            'elapsed_s': elapsed
        }
        print(f"Finished {label_str}, J={J}. Final val_acc={final_acc:.4f}. Time: {elapsed:.1f}s")

# ---------------- Print Summary table ----------------
rows = []
for (label_str, J), info in nc_results.items():
    rows.append({'shard': label_str, 'J': J, 'rounds': info['rounds'], 'final_val_acc': info['final_acc'], 'time_s': info['elapsed_s']})
df = pd.DataFrame(rows).sort_values(['shard','J'])
print("\nSummary (final validation accuracies):")
print(df.to_string(index=False))

# ---------------- Optional: quick plots ----------------
# plot final accuracies grouped by J
plt.figure(figsize=(8,4))
for J in J_values:
    xs = []
    ys = []
    labels = []
    for Nc in Nc_values + ['iid']:
        key = (('iid' if Nc=='iid' else f'Nc{Nc}'), J)
        if key in nc_results:
            xs.append(str(key[0]))
            ys.append(nc_results[key]['final_acc'])
            labels.append(key[0])
    plt.plot(labels, ys, marker='o', label=f'J={J}')
plt.xlabel("Sharding (iid or Nc)")
plt.ylabel("Final val accuracy")
plt.title("Nc experiments: final validation accuracy vs shard type (by J)")
plt.legend()
plt.grid(True)
plt.show()

# plot per-shard example: pick Nc=1 and plot val curve for each J
example_shard = 'Nc1'
plt.figure(figsize=(10,4))
for J in J_values:
    k = (example_shard, J)
    if k in nc_results:
        plt.plot(nc_results[k]['val_accs'], label=f'J={J}')
plt.title(f"Validation accuracy curves for {example_shard}")
plt.xlabel("round")
plt.ylabel("val acc")
plt.legend()
plt.show()
# ---------------- end cell ----------------
